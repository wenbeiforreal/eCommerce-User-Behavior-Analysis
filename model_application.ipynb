# %%
import pandas as pd
import numpy as np
import datetime as dt
from pytz import timezone
import pytz
import matplotlib.pyplot as plt
import seaborn as sns
import squarify
from apyori import apriori

# %% [markdown]
# ## Part I

# %%
df1 = pd.read_csv("2019-Oct.csv")
df2 = pd.read_csv("2019-Nov.csv")

df1.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:00 UTC       view    44600062  2103807459595387724
# 1  2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 2  2019-10-01 00:00:01 UTC       view    17200506  2053013559792632471
# 3  2019-10-01 00:00:01 UTC       view     1307067  2053013558920217191
# 4  2019-10-01 00:00:04 UTC       view     1004237  2053013555631882655
#
#                          category_code     brand    price    user_id  \
# 0                                  NaN  shiseido    35.79  541312140
# 1  appliances.environment.water_heater      aqua    33.20  554748717
# 2           furniture.living_room.sofa       NaN   543.10  519107250
# 3                   computers.notebook    lenovo   251.74  550050854
# 4               electronics.smartphone     apple  1081.98  535871217
#
#                            user_session
# 0  72d76fde-8bb3-4e00-8c23-a032dfed738c
# 1  9333dfbd-b87a-4708-9857-6336556b0fcc
# 2  566511c2-e2e3-422b-b695-cf8e6e792ca8
# 3  7c90fc70-0e80-4590-96f3-13c02c18c713
# 4  c6bd7419-2748-4c56-95b4-8cec9ff8b80d

# %%
# step 1
df1.dropna(axis=0, inplace=True)
df2.dropna(axis=0, inplace=True)

# step 2
frames = [df1, df2]
df = pd.concat(frames)

df
# Out:
#                        event_time event_type  product_id          category_id  \
# 1         2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 3         2019-10-01 00:00:01 UTC       view     1307067  2053013558920217191
# 4         2019-10-01 00:00:04 UTC       view     1004237  2053013555631882655
# 5         2019-10-01 00:00:05 UTC       view     1480613  2053013561092866779
# 8         2019-10-01 00:00:10 UTC       view    28719074  2053013565480109009
# ...                           ...        ...         ...                  ...
# 67501972  2019-11-30 23:59:57 UTC       view    12301059  2053013556311359947
# 67501975  2019-11-30 23:59:58 UTC       view    28719425  2053013565639492569
# 67501976  2019-11-30 23:59:59 UTC       view     1004833  2053013555631882655
# 67501977  2019-11-30 23:59:59 UTC       view     2701706  2053013563911439225
# 67501978  2019-11-30 23:59:59 UTC       view     1004233  2053013555631882655
#
#                                 category_code    brand    price    user_id  \
# 1         appliances.environment.water_heater     aqua    33.20  554748717
# 3                          computers.notebook   lenovo   251.74  550050854
# 4                      electronics.smartphone    apple  1081.98  535871217
# 5                           computers.desktop   pulser   908.62  512742880
# 8                          apparel.shoes.keds    baden   102.71  520571932
# ...                                       ...      ...      ...        ...
# 67501972             construction.tools.drill    bosch   266.16  562661595
# 67501975                        apparel.shoes    baden    62.81  545223467
# 67501976               electronics.smartphone  samsung   167.03  557794415
# 67501977     appliances.kitchen.refrigerators  samsung   566.27  531607492
# 67501978               electronics.smartphone    apple  1312.52  579969851
#
#                                   user_session
# 1         9333dfbd-b87a-4708-9857-6336556b0fcc
# 3         7c90fc70-0e80-4590-96f3-13c02c18c713
# 4         c6bd7419-2748-4c56-95b4-8cec9ff8b80d
# 5         0d0d91c2-c9c2-4e81-90a5-86594dec0db9
# 8         ac1cd4e5-a3ce-4224-a2d7-ff660a105880
# ...                                        ...
# 67501972  7165dc28-9cba-40a0-9ed8-76fd909ccb3b
# 67501975  734c5eef-0742-4f8b-9d22-48f75b0bc359
# 67501976  6fecf566-ebb0-4e70-a243-cdc13ce044cb
# 67501977  368ddc8b-5db9-40fb-b7ff-b6582a1192c0
# 67501978  90aca71c-ed8a-4670-866a-761ebacb732d
#
# [68650184 rows x 9 columns]

# %%
# step 3
data1 = df.drop(['product_id','category_id','category_code','brand'], axis=1)
data1=data1.loc[data1.event_type == 'purchase']
data1.head()
# Out:
#                   event_time event_type   price    user_id  \
# 162  2019-10-01 00:02:14 UTC   purchase  130.76  543272936
# 308  2019-10-01 00:04:37 UTC   purchase  642.69  551377651
# 442  2019-10-01 00:07:07 UTC   purchase   54.42  555332717
# 574  2019-10-01 00:09:26 UTC   purchase  189.91  524601178
# 603  2019-10-01 00:09:54 UTC   purchase  161.98  551377651
#
#                              user_session
# 162  8187d148-3c41-46d4-b0c0-9c08cd9dc564
# 308  3c80f0d6-e9ec-4181-8c5c-837a30be2d68
# 442  1dea3ee2-2ded-42e8-8e7a-4e2ad6ae942f
# 574  2af9b570-0942-4dcd-8f25-4d84fba82553
# 603  3c80f0d6-e9ec-4181-8c5c-837a30be2d68

# %%
data1.dtypes
# Out:
# event_time       object
# event_type       object
# price           float64
# user_id           int64
# user_session     object
# dtype: object

# %%
data1['event_time']=pd.to_datetime(data1['event_time'])
data1.dtypes
# Out:
# event_time      datetime64[ns, UTC]
# event_type                   object
# price                       float64
# user_id                       int64
# user_session                 object
# dtype: object

# %%
# step 4
data1 = data1.groupby(by='user_session').agg(order_date=('event_time',lambda x: x.max()),
                                             user_id=('user_id',lambda x: x.unique()),
                                             quantity=('user_session','count'),
                                             gtv=('price','sum')).reset_index(drop=True)
data1
# Out:
#                        order_date    user_id  quantity     gtv
# 0       2019-10-06 11:34:30+00:00  546521725         1  289.52
# 1       2019-10-25 08:39:11+00:00  560486342         1  171.90
# 2       2019-11-11 03:35:34+00:00  566954797         1  151.61
# 3       2019-10-17 13:37:59+00:00  560744406         2  379.78
# 4       2019-10-15 08:09:02+00:00  520649833         1   90.07
# ...                           ...        ...       ...     ...
# 1025273 2019-10-04 08:53:59+00:00  519348985         1  360.34
# 1025274 2019-11-17 14:47:28+00:00  521378371         1  269.97
# 1025275 2019-11-24 08:34:23+00:00  513821974         1  977.86
# 1025276 2019-11-28 09:41:58+00:00  515196983         2  945.70
# 1025277 2019-11-17 14:12:02+00:00  519073108         1  128.42
#
# [1025278 rows x 4 columns]

# %%
# step 5 
data1["order_date"].max()
# Out:
# Timestamp('2019-11-30 23:59:15+0000', tz='UTC')

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
utc = pytz.utc
by_date = dt.datetime(2019,12,1,0,0,0,tzinfo=pytz.utc)
data1['recent_purchase'] = by_date - data1['order_date']
data1['recent_purchase'].astype('timedelta64[D]')
data1['recent_purchase']= data1['recent_purchase'] / np.timedelta64(1, 'D')
data1.head()
# Out:
#                  order_date    user_id  quantity     gtv  recent_purchase
# 0 2019-10-06 11:34:30+00:00  546521725         1  289.52        55.517708
# 1 2019-10-25 08:39:11+00:00  560486342         1  171.90        36.639456
# 2 2019-11-11 03:35:34+00:00  566954797         1  151.61        19.850301
# 3 2019-10-17 13:37:59+00:00  560744406         2  379.78        44.431956
# 4 2019-10-15 08:09:02+00:00  520649833         1   90.07        46.660394

# %%
# Recency, Frequency, and, Monetary calculation
rfm = data1.groupby('user_id').agg(recency = ('recent_purchase', lambda x:x.min()),
                                  frequency = ('user_id', lambda x:x.count()),
                                  monetary = ('gtv', lambda x:x.sum()))
rfm.head()
# Out:
#              recency  frequency  monetary
# user_id
# 225644257  18.819780          1     40.91
# 253299396  24.546169          1    246.85
# 256164170  10.651921          1    113.23
# 296197073   0.631377          1     51.46
# 299358698  21.860127          1    154.19

# %%
# step 6 
rfm['recency'].describe()
# Out:
# count    533572.000000
# mean         25.516806
# std          17.339359
# min           0.000521
# 25%          13.278426
# 50%          20.908183
# 75%          40.480836
# max          60.992407
# Name: recency, dtype: float64

# %%
rfm['frequency'].describe()
# Out:
# count    533572.000000
# mean          1.921536
# std           2.876131
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max         328.000000
# Name: frequency, dtype: float64

# %%
rfm['monetary'].describe()
# Out:
# count    533572.000000
# mean        834.804170
# std        2490.450855
# min           0.870000
# 25%         154.390000
# 50%         308.860000
# 75%         795.890000
# max      344153.290000
# Name: monetary, dtype: float64

# %%
rfm.quantile(q = [0.20, 0.40, 0.60, 0.80])
# Out:
#        recency  frequency  monetary
# 0.2  10.626563        1.0    131.53
# 0.4  14.474602        1.0    243.51
# 0.6  28.504262        1.0    447.84
# 0.8  44.303067        2.0    977.64

# %%
quartiles = rfm.quantile(q = [0.50, 0.75]).to_dict()
quartiles
# Out:
# {'recency': {0.5: 20.90818287037037, 0.75: 40.48083622685186},
#  'frequency': {0.5: 1.0, 0.75: 2.0},
#  'monetary': {0.5: 308.86, 0.75: 795.89}}

# %%
# step 7
# for Frequency only, as it has duplicates
def f_scoring(x, p, d):
    if x <= d[p][0.50]:
        return 1
    elif x <= d[p][0.75]:
        return 2
    else:
        return 3

# calculate total score per user_id
def total_scoring(df):
    return df['R'] + df['F'] + df['M']

# %%
r_score = range(5,0,-1)
m_score = range(1,6)

r_scoring = pd.qcut(rfm['recency'], q = 5, labels = r_score)
m_scoring = pd.qcut(rfm['monetary'], q = 5, labels = m_score)

rfm = rfm.assign(R = r_scoring.values, M = m_scoring.values)
rfm['F'] = rfm['frequency'].apply(f_scoring, args = ('frequency', quartiles))

# %%
rfm.head(100)
# Out:
#              recency  frequency  monetary  R  M  F
# user_id
# 225644257  18.819780          1     40.91  3  1  1
# 253299396  24.546169          1    246.85  3  3  1
# 256164170  10.651921          1    113.23  4  1  1
# 296197073   0.631377          1     51.46  5  1  1
# 299358698  21.860127          1    154.19  3  2  1
# ...              ...        ...       ... .. .. ..
# 456372497   3.863935          1     28.29  5  1  1
# 456575945  35.840648          1    437.33  2  3  1
# 456810531  32.649699          2    266.70  2  3  2
# 457344986  10.500498          1    195.35  5  2  1
# 457360398  60.817442          1     51.46  1  1  1
#
# [100 rows x 6 columns]

# %%
rfm['total_score'] = rfm.apply(total_scoring, axis=1)
rfm.head(100)
# Out:
#              recency  frequency  monetary  R  M  F  total_score
# user_id
# 225644257  18.819780          1     40.91  3  1  1          5.0
# 253299396  24.546169          1    246.85  3  3  1          7.0
# 256164170  10.651921          1    113.23  4  1  1          6.0
# 296197073   0.631377          1     51.46  5  1  1          7.0
# 299358698  21.860127          1    154.19  3  2  1          6.0
# ...              ...        ...       ... .. .. ..          ...
# 456372497   3.863935          1     28.29  5  1  1          7.0
# 456575945  35.840648          1    437.33  2  3  1          6.0
# 456810531  32.649699          2    266.70  2  3  2          7.0
# 457344986  10.500498          1    195.35  5  2  1          8.0
# 457360398  60.817442          1     51.46  1  1  1          3.0
#
# [100 rows x 7 columns]

# %%
rfm['total_score'].describe()
# Out:
# count    533572.000000
# mean          7.499466
# std           2.574356
# min           3.000000
# 25%           6.000000
# 50%           7.000000
# 75%           9.000000
# max          13.000000
# Name: total_score, dtype: float64

# %%
# plot distribution of total_score for better visualization
plt.figure(figsize = (12,10))
sns.displot(rfm['total_score'], discrete=True, color='steelblue')
plt.savefig('histogram.png', dpi=200)

# %%
# step 8 - define user segmentation
def tiers(df):
    if df['total_score'] >= 11:
        return 'High Value Customer'
    elif ((df['total_score'] >= 8) and (df['total_score'] < 11)):
        return 'Gold Customer'
    elif ((df['total_score'] >= 6) and (df['total_score'] < 8)):
        return 'Silver Customer'
    elif ((df['total_score'] >= 4) and (df['total_score'] < 6)):
        return 'Bronze Customer'
    else:
        return 'Churning'

# %%
rfm['Segmentation'] = rfm.apply(tiers, axis=1)
rfm.head(100)
# Out:
#              recency  frequency  monetary  R  M  F  total_score  \
# user_id
# 225644257  18.819780          1     40.91  3  1  1          5.0
# 253299396  24.546169          1    246.85  3  3  1          7.0
# 256164170  10.651921          1    113.23  4  1  1          6.0
# 296197073   0.631377          1     51.46  5  1  1          7.0
# 299358698  21.860127          1    154.19  3  2  1          6.0
# ...              ...        ...       ... .. .. ..          ...
# 456372497   3.863935          1     28.29  5  1  1          7.0
# 456575945  35.840648          1    437.33  2  3  1          6.0
# 456810531  32.649699          2    266.70  2  3  2          7.0
# 457344986  10.500498          1    195.35  5  2  1          8.0
# 457360398  60.817442          1     51.46  1  1  1          3.0
#
#               Segmentation
# user_id
# 225644257  Bronze Customer
# 253299396  Silver Customer
# 256164170  Silver Customer
# 296197073  Silver Customer
# 299358698  Silver Customer
# ...                    ...
# 456372497  Silver Customer
# 456575945  Silver Customer
# 456810531  Silver Customer
# 457344986    Gold Customer
# 457360398         Churning
#
# [100 rows x 8 columns]

# %%
# step 9
rfm_segmentation = rfm.groupby('Segmentation').agg({
    'recency':'mean',
    'frequency':'mean',
    'monetary':['mean','count']
}).round(0)

rfm_segmentation

# rfm_segmentation = pd.DataFrame(rfm_segmentation)
# Out:
#                     recency frequency monetary
#                        mean      mean     mean   count
# Segmentation
# Bronze Customer        40.0       1.0    160.0  106999
# Churning               52.0       1.0     74.0   23197
# Gold Customer          19.0       2.0    889.0  174683
# High Value Customer     9.0       5.0   2901.0   76022
# Silver Customer        27.0       1.0    332.0  152671

# %%
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 9)
colors = ['gold','lightcyan','orange','indianred','lightsalmon']
counts = [106999, 23197, 174683, 76022, 152671]
squarify.plot(sizes=counts,
             label=['Bronze Customer',
                   'Churning',
                   'Gold Customer',
                   'High Value Customer',
                   'Silver Customer'], alpha=1, color=colors, pad=True,
             text_kwargs={'fontsize':18})
plt.title('RFM Segments', fontsize=25, fontweight='bold')
plt.axis('off')
plt.savefig('rfm.png', dpi=200)
plt.show()

# %% [markdown]
# ## Part II

# %%
# step 1
df['items'] = df.category_code.str.split('.').str[-1]
df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 1  2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 3  2019-10-01 00:00:01 UTC       view     1307067  2053013558920217191
# 4  2019-10-01 00:00:04 UTC       view     1004237  2053013555631882655
# 5  2019-10-01 00:00:05 UTC       view     1480613  2053013561092866779
# 8  2019-10-01 00:00:10 UTC       view    28719074  2053013565480109009
#
#                          category_code   brand    price    user_id  \
# 1  appliances.environment.water_heater    aqua    33.20  554748717
# 3                   computers.notebook  lenovo   251.74  550050854
# 4               electronics.smartphone   apple  1081.98  535871217
# 5                    computers.desktop  pulser   908.62  512742880
# 8                   apparel.shoes.keds   baden   102.71  520571932
#
#                            user_session         items
# 1  9333dfbd-b87a-4708-9857-6336556b0fcc  water_heater
# 3  7c90fc70-0e80-4590-96f3-13c02c18c713      notebook
# 4  c6bd7419-2748-4c56-95b4-8cec9ff8b80d    smartphone
# 5  0d0d91c2-c9c2-4e81-90a5-86594dec0db9       desktop
# 8  ac1cd4e5-a3ce-4224-a2d7-ff660a105880          keds

# %%
data2 = df[['user_id','event_type','items','event_time']]
df_purchases = data2.loc[data2.event_type == 'purchase']
df_purchases = df_purchases[['user_id','items']]
df_purchases.head()
# Out:
#        user_id       items
# 162  543272936  smartphone
# 308  551377651  smartphone
# 442  555332717      toilet
# 574  524601178   headphone
# 603  551377651   headphone

# %%
# step 2
item_cnt = df_purchases.groupby('items', as_index=False).agg(count = ('user_id', lambda x:x.count()))
item_cnt = item_cnt.sort_values('count', ascending=False)
item_cnt.head(50)
# Out:
#               items   count
# 93       smartphone  720067
# 42        headphone   71181
# 113              tv   51726
# 18           clocks   38073
# 121          washer   35739
# 66         notebook   33870
# 116          vacuum   30340
# 79    refrigerators   19291
# 87            shoes   12166
# 103          tablet   11722
# 60        microwave    8600
# 45             iron    8295
# 104       telephone    8069
# 12          blender    7080
# 26          desktop    6635
# 52           kettle    6523
# 67             oven    6028
# 122    water_heater    5969
# 3             alarm    5698
# 73           player    5266
# 75          printer    5189
# 2        air_heater    4923
# 85   sewing_machine    4848
# 100       subwoofer    4794
# 51             keds    4341
# 57     meat_grinder    4309
# 31            drill    4110
# 15         carriage    4103
# 119   videoregister    3969
# 81              saw    2994
# 61            mixer    2966
# 17            chair    2958
# 82           scales    2907
# 36        generator    2882
# 8               bed    2766
# 63          monitor    2643
# 5               bag    2594
# 44             hood    2413
# 43              hob    2342
# 41              hdd    2271
# 39      hair_cutter    2182
# 0          acoustic    2024
# 65            mouse    2016
# 118      videocards    1951
# 109            toys    1808
# 38            grill    1792
# 28       dishwasher    1633
# 27          diapers    1514
# 46    ironing_board    1504
# 10          bicycle    1294

# %%
item_cnt['count'].describe()
# Out:
# count       125.000000
# mean       9670.104000
# std       64807.342127
# min           1.000000
# 25%         129.000000
# 50%         860.000000
# 75%        2958.000000
# max      720067.000000
# Name: count, dtype: float64

# %%
# step 3 - visualising the frequency of items
sns.set(style='whitegrid', rc = {'figure.figsize':(20,4)})
ax = sns.barplot(x='items', y='count', data=item_cnt[item_cnt['count'] >= 1000])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'smartphone'),
#  Text(1, 0, 'headphone'),
#  Text(2, 0, 'tv'),
#  Text(3, 0, 'clocks'),
#  Text(4, 0, 'washer'),
#  Text(5, 0, 'notebook'),
#  Text(6, 0, 'vacuum'),
#  Text(7, 0, 'refrigerators'),
#  Text(8, 0, 'shoes'),
#  Text(9, 0, 'tablet'),
#  Text(10, 0, 'microwave'),
#  Text(11, 0, 'iron'),
#  Text(12, 0, 'telephone'),
#  Text(13, 0, 'blender'),
#  Text(14, 0, 'desktop'),
#  Text(15, 0, 'kettle'),
#  Text(16, 0, 'oven'),
#  Text(17, 0, 'water_heater'),
#  Text(18, 0, 'alarm'),
#  Text(19, 0, 'player'),
#  Text(20, 0, 'printer'),
#  Text(21, 0, 'air_heater'),
#  Text(22, 0, 'sewing_machine'),
#  Text(23, 0, 'subwoofer'),
#  Text(24, 0, 'keds'),
#  Text(25, 0, 'meat_grinder'),
#  Text(26, 0, 'drill'),
#  Text(27, 0, 'carriage'),
#  Text(28, 0, 'videoregister'),
#  Text(29, 0, 'saw'),
#  Text(30, 0, 'mixer'),
#  Text(31, 0, 'chair'),
#  Text(32, 0, 'scales'),
#  Text(33, 0, 'generator'),
#  Text(34, 0, 'bed'),
#  Text(35, 0, 'monitor'),
#  Text(36, 0, 'bag'),
#  Text(37, 0, 'hood'),
#  Text(38, 0, 'hob'),
#  Text(39, 0, 'hdd'),
#  Text(40, 0, 'hair_cutter'),
#  Text(41, 0, 'acoustic'),
#  Text(42, 0, 'mouse'),
#  Text(43, 0, 'videocards'),
#  Text(44, 0, 'toys'),
#  Text(45, 0, 'grill'),
#  Text(46, 0, 'dishwasher'),
#  Text(47, 0, 'diapers'),
#  Text(48, 0, 'ironing_board'),
#  Text(49, 0, 'bicycle'),
#  Text(50, 0, 'juicer'),
#  Text(51, 0, 'coffee_machine'),
#  Text(52, 0, 'cabinet'),
#  Text(53, 0, 'air_conditioner'),
#  Text(54, 0, 'keyboard'),
#  Text(55, 0, 'memory'),
#  Text(56, 0, 'piano'),
#  Text(57, 0, 'table')]

# %%
# step 4
df_each_trans = data2.loc[data2.event_type == 'purchase']
df_each_trans = df_each_trans[['user_id','event_time','items']]
trans = df_each_trans.groupby(['user_id', 'event_time'], as_index=False)['items'].apply(lambda x:','.join(x))

trans.head(50)
# Out:
#                                      user_id               event_time  \
# user_id   event_time
# 225644257 2019-11-12 04:19:31 UTC  225644257  2019-11-12 04:19:31 UTC
# 253299396 2019-11-06 10:53:31 UTC  253299396  2019-11-06 10:53:31 UTC
# 256164170 2019-11-20 08:21:14 UTC  256164170  2019-11-20 08:21:14 UTC
# 296197073 2019-11-30 08:50:49 UTC  296197073  2019-11-30 08:50:49 UTC
# 299358698 2019-11-09 03:21:25 UTC  299358698  2019-11-09 03:21:25 UTC
# 303160429 2019-10-13 13:25:29 UTC  303160429  2019-10-13 13:25:29 UTC
# 304707635 2019-11-13 11:02:34 UTC  304707635  2019-11-13 11:02:34 UTC
# 307138432 2019-11-08 05:14:41 UTC  307138432  2019-11-08 05:14:41 UTC
# 308228668 2019-11-19 11:43:58 UTC  308228668  2019-11-19 11:43:58 UTC
# 310402868 2019-11-11 12:31:35 UTC  310402868  2019-11-11 12:31:35 UTC
# 315835135 2019-11-28 13:02:44 UTC  315835135  2019-11-28 13:02:44 UTC
# 315835876 2019-11-24 07:11:52 UTC  315835876  2019-11-24 07:11:52 UTC
# 323651575 2019-11-13 08:34:55 UTC  323651575  2019-11-13 08:34:55 UTC
# 340041246 2019-10-14 14:45:39 UTC  340041246  2019-10-14 14:45:39 UTC
# 353600697 2019-11-20 09:28:26 UTC  353600697  2019-11-20 09:28:26 UTC
# 366237542 2019-11-19 09:03:56 UTC  366237542  2019-11-19 09:03:56 UTC
#           2019-11-28 03:25:15 UTC  366237542  2019-11-28 03:25:15 UTC
# 369234855 2019-11-18 11:16:41 UTC  369234855  2019-11-18 11:16:41 UTC
# 369801696 2019-11-12 16:13:13 UTC  369801696  2019-11-12 16:13:13 UTC
#           2019-11-12 16:15:49 UTC  369801696  2019-11-12 16:15:49 UTC
#           2019-11-13 08:13:55 UTC  369801696  2019-11-13 08:13:55 UTC
# 378784732 2019-11-10 07:54:48 UTC  378784732  2019-11-10 07:54:48 UTC
# 384989212 2019-10-18 11:19:59 UTC  384989212  2019-10-18 11:19:59 UTC
# 389051600 2019-11-11 07:23:38 UTC  389051600  2019-11-11 07:23:38 UTC
# 392821421 2019-11-19 04:36:13 UTC  392821421  2019-11-19 04:36:13 UTC
# 397810898 2019-11-22 03:49:47 UTC  397810898  2019-11-22 03:49:47 UTC
# 401021311 2019-10-21 04:19:14 UTC  401021311  2019-10-21 04:19:14 UTC
# 402311094 2019-11-07 17:43:18 UTC  402311094  2019-11-07 17:43:18 UTC
# 403013066 2019-10-18 19:07:54 UTC  403013066  2019-10-18 19:07:54 UTC
#           2019-10-18 19:15:13 UTC  403013066  2019-10-18 19:15:13 UTC
# 403810661 2019-11-11 04:19:03 UTC  403810661  2019-11-11 04:19:03 UTC
#           2019-11-27 07:38:55 UTC  403810661  2019-11-27 07:38:55 UTC
# 404851685 2019-11-12 08:12:02 UTC  404851685  2019-11-12 08:12:02 UTC
#           2019-11-13 11:20:08 UTC  404851685  2019-11-13 11:20:08 UTC
#           2019-11-24 07:50:27 UTC  404851685  2019-11-24 07:50:27 UTC
#           2019-11-25 06:18:43 UTC  404851685  2019-11-25 06:18:43 UTC
# 410333972 2019-10-31 12:37:15 UTC  410333972  2019-10-31 12:37:15 UTC
# 413528456 2019-11-27 21:25:44 UTC  413528456  2019-11-27 21:25:44 UTC
# 415423761 2019-11-22 07:46:43 UTC  415423761  2019-11-22 07:46:43 UTC
# 415873351 2019-10-31 06:16:00 UTC  415873351  2019-10-31 06:16:00 UTC
#           2019-10-31 06:19:24 UTC  415873351  2019-10-31 06:19:24 UTC
# 418115333 2019-10-28 16:36:26 UTC  418115333  2019-10-28 16:36:26 UTC
# 419697235 2019-11-08 11:59:08 UTC  419697235  2019-11-08 11:59:08 UTC
# 419993051 2019-11-10 13:21:29 UTC  419993051  2019-11-10 13:21:29 UTC
# 420935067 2019-10-07 08:39:16 UTC  420935067  2019-10-07 08:39:16 UTC
# 420986446 2019-11-27 10:53:40 UTC  420986446  2019-11-27 10:53:40 UTC
#           2019-11-27 10:56:09 UTC  420986446  2019-11-27 10:56:09 UTC
# 421812528 2019-11-23 07:00:19 UTC  421812528  2019-11-23 07:00:19 UTC
# 424827221 2019-11-28 08:32:52 UTC  424827221  2019-11-28 08:32:52 UTC
# 424869855 2019-10-24 11:36:23 UTC  424869855  2019-10-24 11:36:23 UTC
#
#                                            items
# user_id   event_time
# 225644257 2019-11-12 04:19:31 UTC            hdd
# 253299396 2019-11-06 10:53:31 UTC           hood
# 256164170 2019-11-20 08:21:14 UTC   water_heater
# 296197073 2019-11-30 08:50:49 UTC  videoregister
# 299358698 2019-11-09 03:21:25 UTC     smartphone
# 303160429 2019-10-13 13:25:29 UTC         clocks
# 304707635 2019-11-13 11:02:34 UTC     smartphone
# 307138432 2019-11-08 05:14:41 UTC     smartphone
# 308228668 2019-11-19 11:43:58 UTC  ironing_board
# 310402868 2019-11-11 12:31:35 UTC      microwave
# 315835135 2019-11-28 13:02:44 UTC        desktop
# 315835876 2019-11-24 07:11:52 UTC     smartphone
# 323651575 2019-11-13 08:34:55 UTC      telephone
# 340041246 2019-10-14 14:45:39 UTC             tv
# 353600697 2019-11-20 09:28:26 UTC          shoes
# 366237542 2019-11-19 09:03:56 UTC     smartphone
#           2019-11-28 03:25:15 UTC         washer
# 369234855 2019-11-18 11:16:41 UTC     smartphone
# 369801696 2019-11-12 16:13:13 UTC     smartphone
#           2019-11-12 16:15:49 UTC     smartphone
#           2019-11-13 08:13:55 UTC     smartphone
# 378784732 2019-11-10 07:54:48 UTC        bicycle
# 384989212 2019-10-18 11:19:59 UTC           oven
# 389051600 2019-11-11 07:23:38 UTC     smartphone
# 392821421 2019-11-19 04:36:13 UTC         washer
# 397810898 2019-11-22 03:49:47 UTC         vacuum
# 401021311 2019-10-21 04:19:14 UTC             tv
# 402311094 2019-11-07 17:43:18 UTC       carriage
# 403013066 2019-10-18 19:07:54 UTC     smartphone
#           2019-10-18 19:15:13 UTC     smartphone
# 403810661 2019-11-11 04:19:03 UTC     smartphone
#           2019-11-27 07:38:55 UTC     smartphone
# 404851685 2019-11-12 08:12:02 UTC      subwoofer
#           2019-11-13 11:20:08 UTC      subwoofer
#           2019-11-24 07:50:27 UTC         player
#           2019-11-25 06:18:43 UTC         player
# 410333972 2019-10-31 12:37:15 UTC     smartphone
# 413528456 2019-11-27 21:25:44 UTC     smartphone
# 415423761 2019-11-22 07:46:43 UTC     smartphone
# 415873351 2019-10-31 06:16:00 UTC     smartphone
#           2019-10-31 06:19:24 UTC     smartphone
# 418115333 2019-10-28 16:36:26 UTC          mouse
# 419697235 2019-11-08 11:59:08 UTC        blender
# 419993051 2019-11-10 13:21:29 UTC     smartphone
# 420935067 2019-10-07 08:39:16 UTC       notebook
# 420986446 2019-11-27 10:53:40 UTC     smartphone
#           2019-11-27 10:56:09 UTC     smartphone
# 421812528 2019-11-23 07:00:19 UTC         tablet
# 424827221 2019-11-28 08:32:52 UTC     smartphone
# 424869855 2019-10-24 11:36:23 UTC     smartphone

# %%
d = {}
for cus, item in zip(trans['user_id'],trans['items']):
    if cus in d:
        d[cus].append(item)
    else:
        d[cus] = []
        d[cus].append(item)
d
# Out:
# {225644257: ['hdd'],
#  253299396: ['hood'],
#  256164170: ['water_heater'],
#  296197073: ['videoregister'],
#  299358698: ['smartphone'],
#  303160429: ['clocks'],
#  304707635: ['smartphone'],
#  307138432: ['smartphone'],
#  308228668: ['ironing_board'],
#  310402868: ['microwave'],
#  315835135: ['desktop'],
#  315835876: ['smartphone'],
#  323651575: ['telephone'],
#  340041246: ['tv'],
#  353600697: ['shoes'],
#  366237542: ['smartphone', 'washer'],
#  369234855: ['smartphone'],
#  369801696: ['smartphone', 'smartphone', 'smartphone'],
#  378784732: ['bicycle'],
#  384989212: ['oven'],
#  389051600: ['smartphone'],
#  392821421: ['washer'],
#  397810898: ['vacuum'],
#  401021311: ['tv'],
#  402311094: ['carriage'],
#  403013066: ['smartphone', 'smartphone'],
#  403810661: ['smartphone', 'smartphone'],
#  404851685: ['subwoofer', 'subwoofer', 'player', 'player'],
#  410333972: ['smartphone'],
#  413528456: ['smartphone'],
#  415423761: ['smartphone'],
#  415873351: ['smartphone', 'smartphone'],
#  418115333: ['mouse'],
#  419697235: ['blender'],
#  419993051: ['smartphone'],
#  420935067: ['notebook'],
#  420986446: ['smartphone', 'smartphone'],
#  421812528: ['tablet'],
#  424827221: ['smartphone'],
#  424869855: ['smartphone'],
#  426163705: ['vacuum'],
#  426687856: ['water_heater'],
#  427151532: ['bed'],
#  427391662: ['smartphone', 'smartphone'],
#  428293417: ['smartphone'],
#  428718574: ['refrigerators', 'refrigerators'],
#  429474454: ['washer'],
#  430524990: ['smartphone'],
#  431106018: ['smartphone'],
#  431246706: ['smartphone'],
#  431897261: ['smartphone'],
#  433754231: ['oven'],
#  435648894: ['smartphone'],
#  435786120: ['clocks'],
#  435854274: ['refrigerators', 'refrigerators'],
#  436327433: ['smartphone'],
#  437371552: ['smartphone', 'smartphone'],
#  438094845: ['telephone'],
#  438231183: ['vacuum'],
#  438992161: ['smartphone'],
#  439008992: ['smartphone'],
#  439209037: ['carriage'],
#  439637419: ['smartphone'],
#  440471930: ['smartphone'],
#  440756116: ['refrigerators'],
#  441522689: ['smartphone'],
#  442444093: ['smartphone'],
#  442687924: ['smartphone'],
#  443414817: ['smartphone', 'smartphone'],
#  444316141: ['smartphone'],
#  445228646: ['printer', 'printer'],
#  445339240: ['videocards', 'cpu', 'cpu'],
#  445526887: ['smartphone'],
#  446080337: ['smartphone', 'smartphone'],
#  447651770: ['tv'],
#  447698613: ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  448659331: ['telephone'],
#  448984650: ['smartphone'],
#  450121457: ['smartphone', 'tablet'],
#  450275087: ['tv', 'smartphone', 'smartphone'],
#  450756413: ['toster'],
#  451447292: ['smartphone'],
#  451868425: ['smartphone'],
#  451979485: ['smartphone'],
#  452701324: ['smartphone', 'smartphone'],
#  453908841: ['smartphone', 'hair_cutter'],
#  453981473: ['vacuum'],
#  454052851: ['smartphone'],
#  454108351: ['coffee_machine'],
#  454170074: ['smartphone'],
#  454959751: ['smartphone'],
#  455145392: ['smartphone'],
#  455367601: ['smartphone', 'smartphone', 'smartphone'],
#  455460477: ['vacuum'],
#  456056600: ['smartphone'],
#  456372497: ['iron'],
#  456575945: ['tv'],
#  456810531: ['acoustic', 'acoustic'],
#  457344986: ['smartphone'],
#  457360398: ['air_heater'],
#  457703282: ['smartphone'],
#  457999725: ['notebook'],
#  458020849: ['smartphone'],
#  458133649: ['smartphone'],
#  458443142: ['carriage', 'smartphone', 'smartphone'],
#  458524195: ['juicer'],
#  459629038: ['smartphone'],
#  459898402: ['smartphone', 'smartphone', 'smartphone'],
#  460752410: ['smartphone'],
#  461023190: ['acoustic', 'acoustic'],
#  461956439: ['smartphone'],
#  462288298: ['smartphone'],
#  462441012: ['smartphone'],
#  462757549: ['smartphone'],
#  462851739: ['carriage'],
#  462908410: ['smartphone'],
#  463450850: ['smartphone'],
#  463888165: ['smartphone', 'smartphone'],
#  464610644: ['smartphone'],
#  465378521: ['smartphone'],
#  465723791: ['notebook'],
#  466100638: ['smartphone'],
#  466355604: ['tv', 'tv', 'iron'],
#  466936854: ['telephone'],
#  467047496: ['smartphone'],
#  467449679: ['air_heater'],
#  467497498: ['tv'],
#  467576236: ['smartphone', 'smartphone'],
#  467920571: ['headphone'],
#  467991797: ['vacuum'],
#  468103953: ['smartphone'],
#  468108437: ['cooler'],
#  468222201: ['smartphone'],
#  468371772: ['meat_grinder'],
#  468464006: ['smartphone'],
#  469154355: ['smartphone'],
#  469200473: ['smartphone'],
#  469361896: ['smartphone'],
#  469993240: ['smartphone'],
#  470193237: ['smartphone'],
#  470238953: ['smartphone'],
#  470282638: ['smartphone'],
#  470561711: ['smartphone'],
#  470885426: ['smartphone'],
#  470964674: ['smartphone'],
#  471207163: ['tv', 'tv'],
#  471516534: ['air_heater', 'air_heater'],
#  471563068: ['smartphone'],
#  472657655: ['smartphone', 'smartphone'],
#  472682993: ['smartphone'],
#  472990673: ['clocks'],
#  473433580: ['smartphone'],
#  473536790: ['smartphone', 'smartphone', 'smartphone'],
#  473668240: ['mixer'],
#  474035876: ['smartphone', 'smartphone'],
#  474057911: ['video'],
#  474414053: ['oven'],
#  474436533: ['desktop'],
#  474570963: ['microwave'],
#  474593321: ['desktop'],
#  474895559: ['smartphone', 'smartphone', 'smartphone'],
#  475297983: ['drill', 'drill', 'drill'],
#  475602559: ['tablet'],
#  475786534: ['vacuum', 'vacuum', 'vacuum', 'vacuum', 'vacuum', 'meat_grinder'],
#  476094435: ['printer'],
#  476509207: ['water_heater'],
#  476785744: ['vacuum', 'notebook'],
#  477122297: ['smartphone'],
#  477146770: ['refrigerators'],
#  477366703: ['telephone'],
#  477446941: ['smartphone', 'smartphone'],
#  477493644: ['smartphone', 'smartphone'],
#  477652311: ['smartphone'],
#  477733329: ['smartphone'],
#  477809563: ['water_heater'],
#  477974596: ['smartphone'],
#  478122650: ['smartphone'],
#  478367034: ['smartphone', 'smartphone'],
#  478415326: ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  478529085: ['bed', 'smartphone'],
#  478741761: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'headphone'],
#  478849730: ['tv'],
#  479233261: ['motherboard', 'motherboard', 'motherboard', 'motherboard'],
#  479256382: ['smartphone'],
#  479307253: ['refrigerators'],
#  479347578: ['tv'],
#  479360137: ['dishwasher'],
#  479752015: ['smartphone', 'notebook', 'notebook', 'notebook'],
#  479827463: ['smartphone', 'smartphone'],
#  479829447: ['tv', 'tv'],
#  480099190: ['smartphone', 'smartphone'],
#  480194670: ['smartphone'],
#  480339528: ['tv', 'smartphone'],
#  480396877: ['vacuum'],
#  480434060: ['smartphone', 'smartphone'],
#  480631967: ['clocks'],
#  480721150: ['smartphone'],
#  480835273: ['smartphone'],
#  480915045: ['microphone'],
#  481094984: ['tv'],
#  481246452: ['cooler'],
#  481341715: ['grill', 'smartphone', 'grill'],
#  481620504: ['smartphone'],
#  481640416: ['tv'],
#  481644560: ['smartphone'],
#  481691968: ['toster', 'toster'],
#  482026492: ['smartphone'],
#  482482539: ['headphone'],
#  482744714: ['clocks'],
#  482823034: ['smartphone'],
#  483083071: ['printer'],
#  483102654: ['smartphone'],
#  483216114: ['smartphone', 'smartphone'],
#  483226510: ['refrigerators'],
#  484195427: ['tv'],
#  484508019: ['smartphone'],
#  484720551: ['smartphone', 'smartphone'],
#  484811215: ['tablet'],
#  484916124: ['vacuum'],
#  485289776: ['smartphone'],
#  485299568: ['smartphone'],
#  485389107: ['clocks'],
#  485760463: ['videocards'],
#  485909616: ['smartphone'],
#  486095923: ['smartphone'],
#  486098806: ['smartphone', 'smartphone', 'smartphone'],
#  486163257: ['smartphone', 'smartphone'],
#  486212808: ['smartphone'],
#  486559239: ['smartphone'],
#  486614559: ['clocks'],
#  486649015: ['smartphone'],
#  486805198: ['smartphone'],
#  486935336: ['smartphone'],
#  486941340: ['smartphone'],
#  486999716: ['smartphone'],
#  487239036: ['smartphone'],
#  487683064: ['washer'],
#  488123390: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  488379220: ['smartphone'],
#  488473681: ['smartphone'],
#  488476721: ['smartphone'],
#  488592340: ['smartphone'],
#  488892031: ['projector'],
#  488925088: ['smartphone'],
#  489085769: ['smartphone',
#   'smartphone',
#   'tablet',
#   'tablet',
#   'tv',
#   'tv',
#   'smartphone',
#   'smartphone',
#   'tablet',
#   'tablet'],
#  489171912: ['microwave'],
#  489320606: ['smartphone'],
#  489335107: ['smartphone'],
#  489540548: ['smartphone'],
#  490293331: ['acoustic',
#   'headphone',
#   'smartphone',
#   'tv',
#   'photo',
#   'headphone',
#   'tv'],
#  490306970: ['smartphone'],
#  490376337: ['smartphone'],
#  490538682: ['smartphone', 'smartphone'],
#  490607253: ['notebook'],
#  490656246: ['notebook'],
#  491026745: ['smartphone'],
#  491162210: ['smartphone'],
#  491214552: ['hood'],
#  491298120: ['clocks'],
#  491301788: ['smartphone'],
#  491633894: ['smartphone'],
#  491693116: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'headphone',
#   'smartphone',
#   'smartphone'],
#  491866278: ['smartphone'],
#  491929644: ['smartphone'],
#  492048312: ['smartphone'],
#  492103460: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  492140530: ['tv'],
#  492209987: ['welding'],
#  492234274: ['washer'],
#  492719150: ['smartphone'],
#  493275440: ['smartphone'],
#  493591413: ['smartphone'],
#  493613035: ['smartphone', 'smartphone', 'smartphone'],
#  493690536: ['tv', 'tv', 'tv', 'tv'],
#  493783685: ['oven'],
#  493813513: ['smartphone', 'smartphone'],
#  494312717: ['refrigerators', 'blender'],
#  494367224: ['vacuum'],
#  494684292: ['smartphone'],
#  494841527: ['smartphone'],
#  495225215: ['smartphone'],
#  495379087: ['smartphone'],
#  495766314: ['smartphone'],
#  496157842: ['shoes'],
#  496412877: ['monitor'],
#  496432902: ['smartphone'],
#  496605239: ['smartphone'],
#  496683326: ['smartphone', 'telephone', 'telephone'],
#  496689215: ['smartphone'],
#  496779508: ['clocks'],
#  496980106: ['smartphone'],
#  497136912: ['trainer'],
#  497226076: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  497456018: ['smartphone', 'smartphone'],
#  497552274: ['smartphone'],
#  498248490: ['smartphone'],
#  498254384: ['smartphone'],
#  498360472: ['notebook'],
#  498822913: ['smartphone'],
#  498873221: ['acoustic'],
#  499012015: ['smartphone', 'smartphone'],
#  499073215: ['smartphone'],
#  499361632: ['smartphone', 'vacuum'],
#  499441861: ['tv', 'smartphone'],
#  499480531: ['smartphone'],
#  499538223: ['smartphone'],
#  499623195: ['smartphone'],
#  499668583: ['water_heater'],
#  499864844: ['smartphone'],
#  499881190: ['video'],
#  500007005: ['hair_cutter'],
#  500234856: ['smartphone', 'smartphone'],
#  500246310: ['vacuum', 'vacuum', 'tv'],
#  501075402: ['smartphone'],
#  501192468: ['videocards'],
#  501433849: ['smartphone', 'tv'],
#  501624793: ['smartphone'],
#  501673590: ['smartphone'],
#  501772199: ['smartphone'],
#  501808853: ['subwoofer'],
#  502065357: ['smartphone'],
#  502104092: ['smartphone'],
#  502162993: ['smartphone', 'smartphone'],
#  502307194: ['smartphone'],
#  502364367: ['table', 'smartphone'],
#  502403976: ['smartphone'],
#  502462943: ['hob'],
#  502469352: ['notebook'],
#  502522950: ['mixer', 'mixer'],
#  502778793: ['refrigerators', 'refrigerators'],
#  502866642: ['smartphone'],
#  503147181: ['smartphone', 'smartphone'],
#  503173452: ['smartphone'],
#  503205824: ['smartphone'],
#  503305861: ['smartphone'],
#  503600407: ['water_heater'],
#  503626366: ['refrigerators'],
#  503641257: ['hob'],
#  503684910: ['smartphone', 'smartphone'],
#  504060780: ['smartphone'],
#  504064036: ['video', 'video'],
#  504367068: ['hair_cutter', 'hair_cutter', 'hair_cutter'],
#  504373723: ['smartphone'],
#  504429960: ['microwave'],
#  504688131: ['smartphone'],
#  505068510: ['smartphone'],
#  505073581: ['smartphone'],
#  505337629: ['smartphone'],
#  505458985: ['smartphone', 'smartphone', 'smartphone'],
#  505654193: ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  505874320: ['smartphone', 'smartphone'],
#  505899545: ['smartphone'],
#  505899770: ['oven'],
#  505951622: ['oven'],
#  506061331: ['refrigerators'],
#  506124143: ['smartphone'],
#  506168394: ['smartphone', 'smartphone'],
#  506224239: ['smartphone', 'smartphone', 'smartphone'],
#  506240036: ['vacuum'],
#  506255779: ['shoes'],
#  506263642: ['smartphone'],
#  506366879: ['smartphone'],
#  506551375: ['smartphone', 'smartphone'],
#  506710873: ['tv', 'tv', 'tv', 'tv', 'tv'],
#  506796093: ['tv'],
#  506819865: ['smartphone'],
#  507132569: ['smartphone', 'smartphone'],
#  507268493: ['smartphone'],
#  507271525: ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  507427952: ['ironing_board'],
#  507646449: ['smartphone'],
#  507874003: ['smartphone'],
#  507874095: ['smartphone', 'smartphone'],
#  507897148: ['headphone',
#   'headphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'tablet',
#   'smartphone'],
#  508318158: ['tablet'],
#  508584556: ['skates', 'skates', 'desktop'],
#  508593823: ['smartphone', 'smartphone'],
#  508895631: ['notebook', 'hdd', 'memory'],
#  508923534: ['smartphone'],
#  509088815: ['smartphone'],
#  509180654: ['washer', 'tv'],
#  509208358: ['microwave'],
#  509209587: ['smartphone'],
#  509251592: ['smartphone'],
#  509330542: ['smartphone', 'smartphone'],
#  509369355: ['smartphone'],
#  509621494: ['clocks'],
#  509621735: ['smartphone'],
#  510181563: ['smartphone'],
#  510193446: ['smartphone'],
#  510301180: ['tv'],
#  510339002: ['smartphone'],
#  510344108: ['smartphone'],
#  510371880: ['grill'],
#  510374704: ['smartphone'],
#  510514633: ['kettle'],
#  510573447: ['kettle'],
#  510670517: ['smartphone',
#   'clocks',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'headphone'],
#  510780164: ['smartphone'],
#  511142527: ['smartphone'],
#  511231471: ['smartphone'],
#  511410651: ['mouse'],
#  511429363: ['smartphone'],
#  511621906: ['smartphone', 'smartphone', 'smartphone'],
#  511738201: ['smartphone'],
#  511745611: ['scales'],
#  511865542: ['smartphone'],
#  511894935: ['cartrige', 'cartrige'],
#  512068283: ['coffee_machine'],
#  512168831: ['shoes'],
#  512363600: ['smartphone', 'clocks', 'clocks', 'clocks'],
#  512363624: ['drill', 'memory'],
#  512363639: ['subwoofer'],
#  512363650: ['blanket',
#   'iron',
#   'scales',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'tablet'],
#  512363656: ['vacuum'],
#  512363659: ['vacuum'],
#  512363666: ['smartphone'],
#  512363669: ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  512363681: ['hair_cutter'],
#  512363684: ['air_heater'],
#  512363693: ['washer', 'blender'],
#  512363708: ['blender', 'vacuum', 'microphone'],
#  512363712: ['tv', 'meat_grinder', 'tv', 'cabinet', 'mixer'],
#  512363722: ['drill'],
#  512363725: ['smartphone'],
#  512363729: ['clocks'],
#  512363732: ['washer', 'tv', 'meat_grinder', 'meat_grinder', 'meat_grinder'],
#  512363734: ['piano'],
#  512363742: ['smartphone'],
#  512363769: ['clocks', 'clocks'],
#  512363775: ['smartphone', 'vacuum', 'vacuum', 'clocks'],
#  512363780: ['smartphone'],
#  512363791: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'headphone',
#   'headphone'],
#  512363794: ['smartphone', 'smartphone'],
#  512363802: ['acoustic'],
#  512363812: ['smartphone'],
#  512363815: ['monitor',
#   'notebook',
#   'notebook',
#   'notebook',
#   'monitor',
#   'monitor',
#   'monitor'],
#  512363834: ['smartphone'],
#  512363836: ['smartphone'],
#  512363853: ['smartphone', 'smartphone', 'smartphone'],
#  512363857: ['refrigerators'],
#  512363867: ['headphone', 'smartphone'],
#  512363879: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512363885: ['smartphone', 'smartphone'],
#  512363886: ['belt'],
#  512363895: ['tonometer', 'clocks', 'clocks', 'clocks', 'subwoofer', 'vacuum'],
#  512363898: ['headphone'],
#  512363901: ['coffee_grinder', 'coffee_grinder', 'grill', 'grill'],
#  512363921: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512363923: ['tv'],
#  512363926: ['smartphone', 'smartphone'],
#  512363931: ['smartphone', 'smartphone'],
#  512363935: ['smartphone'],
#  512363943: ['desktop'],
#  512363944: ['smartphone'],
#  512363947: ['smartphone'],
#  512363962: ['printer', 'printer', 'desktop'],
#  512363963: ['smartphone'],
#  512363973: ['headphone',
#   'headphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512363975: ['swing'],
#  512363994: ['monitor'],
#  512363997: ['headphone', 'headphone', 'headphone'],
#  512364002: ['kettle'],
#  512364004: ['smartphone'],
#  512364022: ['smartphone', 'washer', 'smartphone'],
#  512364023: ['smartphone'],
#  512364027: ['smartphone', 'smartphone', 'headphone', 'tv'],
#  512364033: ['smartphone'],
#  512364082: ['smartphone'],
#  512364123: ['vacuum', 'smartphone', 'smartphone', 'smartphone'],
#  512364169: ['notebook'],
#  512364177: ['microwave'],
#  512364184: ['notebook', 'notebook'],
#  512364192: ['clocks'],
#  512364235: ['swing'],
#  512364263: ['hair_cutter'],
#  512364293: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'clocks'],
#  512364302: ['smartphone'],
#  512364309: ['iron', 'carriage'],
#  512364323: ['notebook',
#   'notebook',
#   'notebook',
#   'tv',
#   'tv',
#   'tv',
#   'tv',
#   'tv',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'smartphone',
#   'microwave',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop'],
#  512364336: ['tablet'],
#  512364372: ['smartphone', 'smartphone'],
#  512364387: ['headphone'],
#  512364407: ['smartphone'],
#  512364410: ['smartphone'],
#  512364422: ['smartphone'],
#  512364437: ['notebook'],
#  512364455: ['smartphone', 'smartphone'],
#  512364457: ['smartphone'],
#  512364480: ['smartphone'],
#  512364481: ['water_heater'],
#  512364484: ['refrigerators'],
#  512364487: ['toys'],
#  512364508: ['scales'],
#  512364515: ['kettle'],
#  512364526: ['clocks'],
#  512364528: ['compressor', 'tv'],
#  512364533: ['water_heater', 'water_heater', 'water_heater', 'water_heater'],
#  512364545: ['smartphone'],
#  512364557: ['smartphone', 'smartphone'],
#  512364591: ['smartphone'],
#  512364595: ['smartphone'],
#  512364709: ['dishwasher',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'notebook',
#   'smartphone'],
#  512364715: ['telephone'],
#  512364719: ['headphone'],
#  512364735: ['vacuum'],
#  512364736: ['headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone'],
#  512364745: ['washer'],
#  512364746: ['smartphone', 'smartphone'],
#  512364756: ['vacuum'],
#  512364757: ['microwave', 'microwave'],
#  512364767: ['headphone', 'headphone', 'headphone', 'headphone'],
#  512364787: ['smartphone', 'smartphone'],
#  512364788: ['smartphone', 'headphone', 'clocks', 'clocks', 'headphone'],
#  512364795: ['smartphone', 'smartphone', 'smartphone'],
#  512364816: ['alarm', 'player'],
#  512364835: ['vacuum'],
#  512364836: ['microwave'],
#  512364839: ['smartphone'],
#  512364875: ['smartphone'],
#  512364888: ['smartphone', 'ballet_shoes', 'shoes'],
#  512364896: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512364913: ['smartphone', 'smartphone'],
#  512364920: ['smartphone', 'smartphone'],
#  512364954: ['tv'],
#  512364977: ['clocks', 'tv'],
#  512364992: ['grill'],
#  512365063: ['smartphone'],
#  512365079: ['headphone'],
#  512365112: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512365119: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512365134: ['notebook'],
#  512365189: ['smartphone'],
#  512365193: ['washer'],
#  512365270: ['microwave', 'meat_grinder', 'piano', 'acoustic', 'meat_grinder'],
#  512365272: ['oven'],
#  512365299: ['smartphone'],
#  512365304: ['headphone', 'hob'],
#  512365322: ['smartphone'],
#  512365334: ['smartphone'],
#  512365338: ['headphone'],
#  512365430: ['smartphone'],
#  512365434: ['vacuum'],
#  512365459: ['smartphone'],
#  512365496: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'clocks',
#   'clocks'],
#  512365511: ['faucet', 'hood'],
#  512365521: ['meat_grinder', 'meat_grinder', 'meat_grinder'],
#  512365529: ['smartphone'],
#  512365536: ['microwave'],
#  512365538: ['washer'],
#  512365547: ['notebook', 'water_heater'],
#  512365577: ['smartphone', 'shoes', 'smartphone'],
#  512365581: ['smartphone'],
#  512365599: ['clocks', 'clocks', 'smartphone'],
#  512365639: ['notebook', 'washer'],
#  512365641: ['swing', 'swing', 'carriage', 'carriage', 'chair', 'chair'],
#  512365674: ['tv', 'smartphone'],
#  512365680: ['video', 'video'],
#  512365686: ['headphone', 'headphone'],
#  512365722: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512365729: ['kettle',
#   'sewing_machine',
#   'sewing_machine',
#   'clocks',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'skates',
#   'kettle'],
#  512365732: ['smartphone', 'drill', 'smartphone'],
#  512365764: ['headphone', 'headphone', 'smartphone'],
#  512365769: ['shoes', 'kettle', 'shoes'],
#  512365815: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512365864: ['videoregister',
#   'alarm',
#   'videoregister',
#   'player',
#   'alarm',
#   'videoregister',
#   'videoregister',
#   'alarm',
#   'alarm',
#   'alarm',
#   'alarm',
#   'player',
#   'player',
#   'alarm'],
#  512365869: ['smartphone'],
#  512365874: ['monitor'],
#  512365904: ['smartphone'],
#  512365958: ['smartphone'],
#  512365971: ['smartphone', 'smartphone'],
#  512365996: ['headphone'],
#  512366029: ['smartphone'],
#  512366036: ['smartphone', 'smartphone', 'smartphone'],
#  512366040: ['smartphone'],
#  512366068: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512366080: ['grill', 'grill'],
#  512366092: ['smartphone', 'smartphone'],
#  512366132: ['clocks'],
#  512366165: ['smartphone'],
#  512366169: ['microwave'],
#  512366178: ['smartphone'],
#  512366186: ['drill'],
#  512366225: ['smartphone',
#   'tv',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512366238: ['tv'],
#  512366245: ['smartphone', 'smartphone', 'smartphone', 'clocks', 'smartphone'],
#  512366270: ['blender',
#   'tablet',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'coffee_grinder',
#   'coffee_grinder',
#   'grill',
#   'grill',
#   'refrigerators',
#   'smartphone'],
#  512366272: ['washer'],
#  512366274: ['smartphone'],
#  512366308: ['microwave'],
#  512366339: ['smartphone', 'smartphone'],
#  512366358: ['smartphone', 'clocks', 'smartphone', 'smartphone', 'smartphone'],
#  512366378: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'projector',
#   'projector',
#   'tv',
#   'tv',
#   'tv',
#   'tv',
#   'grill',
#   'smartphone',
#   'refrigerators',
#   'refrigerators'],
#  512366424: ['refrigerators'],
#  512366455: ['notebook'],
#  512366489: ['smartphone'],
#  512366495: ['smartphone'],
#  512366512: ['toys'],
#  512366561: ['smartphone'],
#  512366580: ['smartphone'],
#  512366600: ['smartphone', 'smartphone', 'diapers'],
#  512366631: ['smartphone', 'smartphone'],
#  512366654: ['tv'],
#  512366670: ['smartphone'],
#  512366675: ['smartphone'],
#  512366683: ['headphone'],
#  512366705: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512366707: ['smartphone'],
#  512366745: ['vacuum', 'tv', 'kettle'],
#  512366772: ['clocks'],
#  512366794: ['shoes', 'drill'],
#  512366827: ['mixer', 'mixer'],
#  512366835: ['shoes', 'shoes'],
#  512366887: ['tv', 'tv', 'tv', 'tv', 'tv', 'blender'],
#  512366905: ['headphone'],
#  512366907: ['clocks', 'clocks'],
#  512366912: ['smartphone'],
#  512366925: ['smartphone'],
#  512366935: ['shoes', 'shoes', 'shoes', 'shoes', 'tablet'],
#  512366944: ['smartphone'],
#  512366949: ['smartphone'],
#  512366962: ['smartphone'],
#  512366966: ['iron'],
#  512366982: ['smartphone', 'tv'],
#  512367004: ['tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'clocks',
#   'tablet'],
#  512367006: ['headphone'],
#  512367025: ['smartphone'],
#  512367045: ['smartphone', 'smartphone', 'smartphone'],
#  512367048: ['air_heater', 'air_heater'],
#  512367071: ['smartphone'],
#  512367099: ['smartphone', 'smartphone', 'smartphone'],
#  512367128: ['smartphone'],
#  512367157: ['headphone'],
#  512367226: ['grill'],
#  512367258: ['smartphone'],
#  512367267: ['ironing_board', 'shoes', 'shoes'],
#  512367296: ['scales', 'scales', 'scales', 'scales', 'sewing_machine'],
#  512367312: ['desktop'],
#  512367325: ['smartphone'],
#  512367342: ['monitor'],
#  512367358: ['refrigerators',
#   'refrigerators',
#   'refrigerators',
#   'refrigerators',
#   'refrigerators',
#   'refrigerators'],
#  512367362: ['desktop'],
#  512367396: ['washer', 'smartphone'],
#  512367400: ['telephone'],
#  512367412: ['light'],
#  512367449: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512367501: ['chair'],
#  512367520: ['smartphone'],
#  512367522: ['smartphone'],
#  512367528: ['air_heater'],
#  512367531: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512367534: ['washer',
#   'shoes',
#   'shoes',
#   'shoes',
#   'shoes',
#   'vacuum',
#   'shoes',
#   'shoes',
#   'shoes'],
#  512367556: ['refrigerators', 'washer'],
#  512367572: ['welding'],
#  512367576: ['videoregister'],
#  512367587: ['vacuum'],
#  512367626: ['smartphone'],
#  512367651: ['headphone', 'headphone'],
#  512367668: ['smartphone',
#   'vacuum',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512367687: ['table'],
#  512367694: ['tv'],
#  512367757: ['toys'],
#  512367789: ['shoes'],
#  512367800: ['vacuum', 'vacuum'],
#  512367811: ['smartphone'],
#  512367863: ['smartphone'],
#  512367865: ['shoes', 'keds'],
#  512367874: ['shoes'],
#  512367876: ['smartphone', 'iron'],
#  512367877: ['tv'],
#  512367888: ['smartphone', 'smartphone', 'smartphone'],
#  512367895: ['washer', 'tv', 'iron', 'vacuum', 'washer', 'dishwasher'],
#  512367911: ['subwoofer', 'subwoofer'],
#  512367923: ['alarm'],
#  512367935: ['tv'],
#  512367955: ['smartphone', 'tv'],
#  512367956: ['headphone'],
#  512367979: ['smartphone'],
#  512368012: ['smartphone'],
#  512368026: ['smartphone', 'smartphone'],
#  512368047: ['subwoofer'],
#  512368054: ['smartphone'],
#  512368075: ['tv'],
#  512368087: ['smartphone'],
#  512368119: ['smartphone', 'smartphone', 'smartphone'],
#  512368130: ['headphone'],
#  512368135: ['smartphone'],
#  512368168: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512368199: ['smartphone'],
#  512368214: ['water_heater'],
#  512368226: ['refrigerators', 'refrigerators', 'refrigerators'],
#  512368232: ['tv'],
#  512368269: ['alarm'],
#  512368272: ['smartphone'],
#  512368285: ['smartphone'],
#  512368294: ['videocards', 'motherboard'],
#  512368308: ['smartphone', 'smartphone'],
#  512368333: ['smartphone', 'tablet', 'tablet', 'tablet'],
#  512368345: ['notebook'],
#  512368347: ['smartphone'],
#  512368363: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512368376: ['smartphone'],
#  512368388: ['headphone'],
#  512368466: ['smartphone'],
#  512368481: ['headphone'],
#  512368482: ['smartphone'],
#  512368490: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512368578: ['smartphone'],
#  512368594: ['smartphone', 'smartphone', 'smartphone'],
#  512368644: ['washer', 'washer', 'washer'],
#  512368669: ['shoes'],
#  512368678: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512368680: ['clocks'],
#  512368705: ['smartphone'],
#  512368789: ['tv', 'tv'],
#  512368833: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512368842: ['clocks'],
#  512368866: ['smartphone', 'clocks'],
#  512368867: ['carriage', 'carriage'],
#  512368869: ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  512368875: ['clocks'],
#  512368876: ['smartphone'],
#  512368893: ['smartphone', 'smartphone', 'notebook', 'notebook'],
#  512368898: ['headphone'],
#  512368933: ['headphone', 'smartphone'],
#  512368941: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512368948: ['blender'],
#  512368961: ['smartphone'],
#  512368966: ['smartphone'],
#  512368992: ['hair_cutter'],
#  512369008: ['tv'],
#  512369042: ['smartphone', 'smartphone', 'smartphone'],
#  512369076: ['hair_cutter'],
#  512369153: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512369168: ['oven'],
#  512369198: ['smartphone'],
#  512369219: ['drill', 'drill'],
#  512369242: ['tv'],
#  512369246: ['tv'],
#  512369249: ['headphone'],
#  512369252: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512369259: ['smartphone'],
#  512369324: ['smartphone', 'smartphone'],
#  512369423: ['generator'],
#  512369431: ['smartphone', 'headphone'],
#  512369436: ['printer'],
#  512369453: ['smartphone'],
#  512369456: ['smartphone', 'smartphone', 'winch'],
#  512369483: ['washer'],
#  512369494: ['tablet'],
#  512369517: ['smartphone'],
#  512369537: ['smartphone'],
#  512369542: ['smartphone', 'smartphone'],
#  512369549: ['smartphone'],
#  512369579: ['smartphone'],
#  512369610: ['vacuum'],
#  512369659: ['vacuum'],
#  512369685: ['videoregister', 'videoregister'],
#  512369692: ['headphone'],
#  512369703: ['tv'],
#  512369785: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512369813: ['smartphone',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'bed'],
#  512369835: ['headphone'],
#  512369854: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512369857: ['tv'],
#  512369878: ['photo',
#   'photo',
#   'photo',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'photo',
#   'desktop',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'notebook',
#   'notebook',
#   'smartphone',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'keds',
#   'shoes',
#   'notebook',
#   'notebook',
#   'photo',
#   'notebook',
#   'photo',
#   'headphone',
#   'headphone',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'headphone',
#   'notebook',
#   'notebook',
#   'headphone',
#   'notebook',
#   'notebook'],
#  512369885: ['telephone',
#   'shoes',
#   'headphone',
#   'tablet',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'smartphone',
#   'headphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'headphone'],
#  512369896: ['headphone'],
#  512369905: ['videocards', 'videocards', 'videocards'],
#  512369908: ['smartphone', 'smartphone', 'smartphone'],
#  512369912: ['smartphone'],
#  512369920: ['drill', 'drill', 'tablet'],
#  512369932: ['notebook', 'notebook', 'notebook'],
#  512369937: ['welding', 'saw'],
#  512369940: ['videoregister', 'headphone', 'headphone'],
#  512369958: ['smartphone', 'grill'],
#  512369962: ['smartphone', 'smartphone', 'hdd'],
#  512369991: ['tv'],
#  512369999: ['coffee_machine', 'coffee_machine'],
#  512370003: ['smartphone'],
#  512370018: ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  512370054: ['refrigerators', 'microwave', 'microwave'],
#  512370056: ['headphone'],
#  512370073: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'headphone',
#   'headphone'],
#  512370084: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'headphone',
#   'smartphone',
#   'smartphone',
#   'clocks',
#   'headphone',
#   'headphone',
#   'headphone',
#   'smartphone'],
#  512370113: ['microwave', 'microwave'],
#  512370121: ['smartphone', 'smartphone'],
#  512370123: ['dishwasher', 'tv'],
#  512370162: ['generator',
#   'smartphone',
#   'smartphone',
#   'sewing_machine',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'carriage',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'diapers',
#   'smartphone',
#   'smartphone',
#   'skates',
#   'skates',
#   'air_heater',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512370169: ['kettle',
#   'blanket',
#   'blanket',
#   'blanket',
#   'ironing_board',
#   'ironing_board',
#   'headphone'],
#  512370237: ['smartphone'],
#  512370239: ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  512370246: ['tablet'],
#  512370254: ['smartphone', 'smartphone', 'smartphone'],
#  512370260: ['tv'],
#  512370270: ['headphone'],
#  512370284: ['tv'],
#  512370287: ['smartphone'],
#  512370298: ['vacuum', 'headphone'],
#  512370324: ['mouse', 'desktop', 'desktop'],
#  512370329: ['washer'],
#  512370349: ['smartphone'],
#  512370370: ['oven', 'smartphone'],
#  512370372: ['smartphone', 'smartphone', 'tv'],
#  512370388: ['kettle'],
#  512370396: ['notebook'],
#  512370412: ['toster'],
#  512370414: ['washer'],
#  512370432: ['smartphone'],
#  512370461: ['tv'],
#  512370486: ['clocks', 'smartphone', 'smartphone'],
#  512370496: ['notebook'],
#  512370533: ['oven'],
#  512370592: ['refrigerators'],
#  512370628: ['smartphone', 'tv', 'smartphone'],
#  512370660: ['vacuum',
#   'vacuum',
#   'vacuum',
#   'vacuum',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'coffee_machine',
#   'smartphone'],
#  512370686: ['smartphone', 'smartphone'],
#  512370693: ['tv'],
#  512370698: ['cabinet', 'cabinet'],
#  512370712: ['smartphone'],
#  512370726: ['smartphone', 'smartphone'],
#  512370733: ['hood'],
#  512370765: ['monitor'],
#  512370780: ['clocks'],
#  512370823: ['desktop'],
#  512370829: ['coffee_machine', 'vacuum'],
#  512370835: ['smartphone'],
#  512370841: ['smartphone'],
#  512370845: ['tv'],
#  512370859: ['smartphone'],
#  512370865: ['headphone', 'headphone'],
#  512370866: ['smartphone'],
#  512370868: ['smartphone'],
#  512370882: ['smartphone'],
#  512370917: ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  512370970: ['smartphone'],
#  512370995: ['headphone', 'headphone', 'smartphone', 'smartphone'],
#  512371004: ['hood'],
#  512371009: ['smartphone'],
#  512371020: ['kettle'],
#  512371027: ['air_conditioner'],
#  512371073: ['ironing_board'],
#  512371084: ['washer', 'tv'],
#  512371090: ['washer',
#   'washer',
#   'smartphone',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer'],
#  512371105: ['keyboard', 'keyboard'],
#  512371110: ['smartphone', 'headphone'],
#  512371192: ['clocks'],
#  512371195: ['smartphone'],
#  512371207: ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  512371231: ['headphone'],
#  512371297: ['smartphone', 'smartphone', 'scales'],
#  512371341: ['washer'],
#  512371363: ['notebook', 'notebook'],
#  512371395: ['refrigerators', 'washer'],
#  512371403: ['blender'],
#  512371411: ['smartphone'],
#  512371416: ['chair', 'chair', 'carriage'],
#  512371446: ['smartphone'],
#  512371473: ['headphone'],
#  512371481: ['sewing_machine'],
#  512371555: ['clocks',
#   'clocks',
#   'shoes',
#   'cabinet',
#   'shoes',
#   'moccasins',
#   'shoes',
#   'shoes',
#   'shoes',
#   'vacuum',
#   'vacuum',
#   'vacuum',
#   'tv',
#   'vacuum',
#   'vacuum',
#   'desktop',
#   'cabinet',
#   'clocks',
#   'toys',
#   'vacuum',
#   'clocks',
#   'kettle',
#   'cabinet',
#   'tv',
#   'smartphone',
#   'smartphone',
#   'toys',
#   'sofa',
#   'sofa',
#   'faucet',
#   'faucet',
#   'smartphone',
#   'faucet',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'vacuum',
#   'smartphone',
#   'smartphone'],
#  512371612: ['smartphone'],
#  512371623: ['headphone'],
#  512371625: ['keds'],
#  512371638: ['smartphone'],
#  512371641: ['juicer'],
#  512371680: ['smartphone', 'notebook'],
#  512371704: ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  512371719: ['alarm'],
#  512371743: ['grill', 'air_heater', 'smartphone', 'smartphone'],
#  512371767: ['smartphone', 'smartphone'],
#  512371790: ['smartphone'],
#  512371791: ['washer'],
#  512371794: ['smartphone'],
#  512371802: ['smartphone'],
#  512371824: ['clocks', 'smartphone'],
#  512371825: ['smartphone'],
#  512371841: ['smartphone'],
#  512371868: ['smartphone'],
#  512371871: ['smartphone'],
#  512371872: ['clocks'],
#  512371883: ['smartphone'],
#  512371887: ['hdd'],
#  512371937: ['alarm', 'tv'],
#  512371951: ['player'],
#  512371970: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512371976: ['headphone'],
#  512371994: ['smartphone', 'smartphone'],
#  512372011: ['smartphone', 'water_heater'],
#  512372012: ['clocks',
#   'clocks',
#   'clocks',
#   'smartphone',
#   'clocks',
#   'clocks',
#   'clocks',
#   'clocks',
#   'clocks',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'alarm'],
#  512372017: ['smartphone'],
#  512372105: ['smartphone'],
#  512372136: ['tonometer', 'water_heater'],
#  512372149: ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  512372185: ['keyboard', 'keyboard', 'keyboard'],
#  512372203: ['saw', 'smartphone'],
#  512372215: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512372217: ['headphone',
#   'smartphone',
#   'headphone',
#   'headphone',
#   'smartphone'],
#  512372255: ['smartphone'],
#  512372263: ['headphone'],
#  512372266: ['tv'],
#  512372290: ['smartphone'],
#  512372307: ['alarm',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'alarm',
#   'alarm'],
#  512372342: ['smartphone'],
#  512372375: ['smartphone'],
#  512372400: ['smartphone'],
#  512372406: ['smartphone'],
#  512372408: ['tablet'],
#  512372414: ['smartphone', 'smartphone'],
#  512372445: ['carriage',
#   'smartphone',
#   'carriage',
#   'smartphone',
#   'vacuum',
#   'smartphone',
#   'smartphone'],
#  512372455: ['headphone'],
#  512372458: ['refrigerators',
#   'refrigerators',
#   'smartphone',
#   'refrigerators',
#   'refrigerators',
#   'refrigerators',
#   'refrigerators',
#   'refrigerators',
#   'refrigerators',
#   'scales',
#   'meat_grinder'],
#  512372488: ['smartphone'],
#  512372497: ['smartphone'],
#  512372529: ['smartphone', 'smartphone', 'smartphone'],
#  512372533: ['smartphone', 'clocks'],
#  512372543: ['microwave'],
#  512372546: ['bag'],
#  512372550: ['vacuum'],
#  512372603: ['smartphone'],
#  512372649: ['smartphone'],
#  512372651: ['notebook'],
#  512372673: ['photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'smartphone',
#   'photo',
#   'photo',
#   'smartphone',
#   'photo',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'tablet',
#   'tablet',
#   'tablet',
#   'smartphone',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'headphone',
#   'headphone',
#   'smartphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'photo',
#   'headphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512372674: ['smartphone', 'smartphone'],
#  512372676: ['smartphone', 'smartphone'],
#  512372678: ['scales'],
#  512372683: ['headphone'],
#  512372691: ['tv', 'microwave'],
#  512372698: ['smartphone'],
#  512372715: ['tv'],
#  512372746: ['smartphone', 'headphone', 'headphone', 'tv'],
#  512372774: ['notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'mouse',
#   'mouse',
#   'mouse',
#   'tablet',
#   'tablet',
#   'tablet',
#   'notebook',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'headphone',
#   'smartphone'],
#  512372799: ['headphone'],
#  512372829: ['smartphone'],
#  512372876: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512372900: ['smartphone', 'hob', 'oven'],
#  512372912: ['smartphone', 'headphone'],
#  512372916: ['smartphone', 'smartphone'],
#  512372979: ['smartphone', 'smartphone'],
#  512373002: ['smartphone'],
#  512373004: ['smartphone', 'smartphone'],
#  512373029: ['smartphone',
#   'tv',
#   'tv',
#   'tv',
#   'refrigerators',
#   'washer',
#   'refrigerators',
#   'refrigerators',
#   'refrigerators',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512373050: ['vacuum'],
#  512373052: ['sofa', 'table'],
#  512373054: ['hood', 'washer', 'vacuum', 'smartphone'],
#  512373117: ['washer', 'washer'],
#  512373126: ['desktop'],
#  512373132: ['washer', 'smartphone'],
#  512373142: ['kettle', 'smartphone'],
#  512373203: ['smartphone', 'smartphone', 'chair', 'smartphone', 'clocks'],
#  512373210: ['smartphone'],
#  512373214: ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  512373231: ['smartphone'],
#  512373237: ['clocks'],
#  512373244: ['headphone'],
#  512373271: ['smartphone', 'smartphone'],
#  512373322: ['smartphone', 'smartphone'],
#  512373343: ['smartphone',
#   'smartphone',
#   'washer',
#   'smartphone',
#   'washer',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'washer',
#   'washer'],
#  512373345: ['headphone'],
#  512373417: ['tv', 'tv'],
#  512373427: ['notebook'],
#  512373428: ['smartphone'],
#  512373434: ['smartphone', 'memory'],
#  512373439: ['smartphone'],
#  512373454: ['smartphone', 'smartphone'],
#  512373455: ['notebook',
#   'fan',
#   'coffee_machine',
#   'coffee_machine',
#   'coffee_machine'],
#  512373469: ['clocks'],
#  512373495: ['carriage'],
#  512373516: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'subwoofer'],
#  512373523: ['smartphone', 'smartphone'],
#  512373537: ['drill', 'smartphone'],
#  512373557: ['smartphone', 'smartphone', 'smartphone'],
#  512373584: ['smartphone'],
#  512373593: ['scales', 'notebook'],
#  512373616: ['refrigerators', 'oven', 'hob', 'hood', 'washer'],
#  512373646: ['smartphone'],
#  512373650: ['smartphone'],
#  512373688: ['tv', 'vacuum', 'oven', 'oven', 'oven', 'oven'],
#  512373717: ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  512373726: ['clocks', 'smartphone'],
#  512373738: ['headphone', 'smartphone'],
#  512373771: ['notebook'],
#  512373776: ['table'],
#  512373788: ['smartphone'],
#  512373797: ['washer'],
#  512373817: ['vacuum'],
#  512373833: ['notebook', 'tv', 'tv'],
#  512373834: ['washer'],
#  512373843: ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  512373849: ['headphone',
#   'headphone',
#   'headphone',
#   'toys',
#   'headphone',
#   'headphone',
#   'headphone',
#   'scales',
#   'scales'],
#  512373870: ['vacuum', 'smartphone'],
#  512373871: ['blanket'],
#  512373885: ['smartphone'],
#  512373905: ['smartphone'],
#  512373909: ['kettle', 'kettle'],
#  512373931: ['vacuum', 'smartphone'],
#  512373946: ['smartphone', 'smartphone'],
#  512373969: ['smartphone', 'smartphone'],
#  512374012: ['cooler'],
#  512374044: ['smartphone'],
#  ...}

# %%
transactions = []
for trans in d.values():
    transactions.append(trans)
transactions
# Out:
# [['hdd'],
#  ['hood'],
#  ['water_heater'],
#  ['videoregister'],
#  ['smartphone'],
#  ['clocks'],
#  ['smartphone'],
#  ['smartphone'],
#  ['ironing_board'],
#  ['microwave'],
#  ['desktop'],
#  ['smartphone'],
#  ['telephone'],
#  ['tv'],
#  ['shoes'],
#  ['smartphone', 'washer'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['bicycle'],
#  ['oven'],
#  ['smartphone'],
#  ['washer'],
#  ['vacuum'],
#  ['tv'],
#  ['carriage'],
#  ['smartphone', 'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['subwoofer', 'subwoofer', 'player', 'player'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['mouse'],
#  ['blender'],
#  ['smartphone'],
#  ['notebook'],
#  ['smartphone', 'smartphone'],
#  ['tablet'],
#  ['smartphone'],
#  ['smartphone'],
#  ['vacuum'],
#  ['water_heater'],
#  ['bed'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['refrigerators', 'refrigerators'],
#  ['washer'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['oven'],
#  ['smartphone'],
#  ['clocks'],
#  ['refrigerators', 'refrigerators'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['telephone'],
#  ['vacuum'],
#  ['smartphone'],
#  ['smartphone'],
#  ['carriage'],
#  ['smartphone'],
#  ['smartphone'],
#  ['refrigerators'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['printer', 'printer'],
#  ['videocards', 'cpu', 'cpu'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['tv'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['telephone'],
#  ['smartphone'],
#  ['smartphone', 'tablet'],
#  ['tv', 'smartphone', 'smartphone'],
#  ['toster'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone', 'hair_cutter'],
#  ['vacuum'],
#  ['smartphone'],
#  ['coffee_machine'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['vacuum'],
#  ['smartphone'],
#  ['iron'],
#  ['tv'],
#  ['acoustic', 'acoustic'],
#  ['smartphone'],
#  ['air_heater'],
#  ['smartphone'],
#  ['notebook'],
#  ['smartphone'],
#  ['smartphone'],
#  ['carriage', 'smartphone', 'smartphone'],
#  ['juicer'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['smartphone'],
#  ['acoustic', 'acoustic'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['carriage'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['notebook'],
#  ['smartphone'],
#  ['tv', 'tv', 'iron'],
#  ['telephone'],
#  ['smartphone'],
#  ['air_heater'],
#  ['tv'],
#  ['smartphone', 'smartphone'],
#  ['headphone'],
#  ['vacuum'],
#  ['smartphone'],
#  ['cooler'],
#  ['smartphone'],
#  ['meat_grinder'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['tv', 'tv'],
#  ['air_heater', 'air_heater'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['clocks'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['mixer'],
#  ['smartphone', 'smartphone'],
#  ['video'],
#  ['oven'],
#  ['desktop'],
#  ['microwave'],
#  ['desktop'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['drill', 'drill', 'drill'],
#  ['tablet'],
#  ['vacuum', 'vacuum', 'vacuum', 'vacuum', 'vacuum', 'meat_grinder'],
#  ['printer'],
#  ['water_heater'],
#  ['vacuum', 'notebook'],
#  ['smartphone'],
#  ['refrigerators'],
#  ['telephone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['water_heater'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['bed', 'smartphone'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'headphone'],
#  ['tv'],
#  ['motherboard', 'motherboard', 'motherboard', 'motherboard'],
#  ['smartphone'],
#  ['refrigerators'],
#  ['tv'],
#  ['dishwasher'],
#  ['smartphone', 'notebook', 'notebook', 'notebook'],
#  ['smartphone', 'smartphone'],
#  ['tv', 'tv'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['tv', 'smartphone'],
#  ['vacuum'],
#  ['smartphone', 'smartphone'],
#  ['clocks'],
#  ['smartphone'],
#  ['smartphone'],
#  ['microphone'],
#  ['tv'],
#  ['cooler'],
#  ['grill', 'smartphone', 'grill'],
#  ['smartphone'],
#  ['tv'],
#  ['smartphone'],
#  ['toster', 'toster'],
#  ['smartphone'],
#  ['headphone'],
#  ['clocks'],
#  ['smartphone'],
#  ['printer'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['refrigerators'],
#  ['tv'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['tablet'],
#  ['vacuum'],
#  ['smartphone'],
#  ['smartphone'],
#  ['clocks'],
#  ['videocards'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['clocks'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['washer'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['projector'],
#  ['smartphone'],
#  ['smartphone',
#   'smartphone',
#   'tablet',
#   'tablet',
#   'tv',
#   'tv',
#   'smartphone',
#   'smartphone',
#   'tablet',
#   'tablet'],
#  ['microwave'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['acoustic', 'headphone', 'smartphone', 'tv', 'photo', 'headphone', 'tv'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['notebook'],
#  ['notebook'],
#  ['smartphone'],
#  ['smartphone'],
#  ['hood'],
#  ['clocks'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'headphone',
#   'smartphone',
#   'smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['tv'],
#  ['welding'],
#  ['washer'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['tv', 'tv', 'tv', 'tv'],
#  ['oven'],
#  ['smartphone', 'smartphone'],
#  ['refrigerators', 'blender'],
#  ['vacuum'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['shoes'],
#  ['monitor'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'telephone', 'telephone'],
#  ['smartphone'],
#  ['clocks'],
#  ['smartphone'],
#  ['trainer'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['notebook'],
#  ['smartphone'],
#  ['acoustic'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['smartphone', 'vacuum'],
#  ['tv', 'smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['water_heater'],
#  ['smartphone'],
#  ['video'],
#  ['hair_cutter'],
#  ['smartphone', 'smartphone'],
#  ['vacuum', 'vacuum', 'tv'],
#  ['smartphone'],
#  ['videocards'],
#  ['smartphone', 'tv'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['subwoofer'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['table', 'smartphone'],
#  ['smartphone'],
#  ['hob'],
#  ['notebook'],
#  ['mixer', 'mixer'],
#  ['refrigerators', 'refrigerators'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['water_heater'],
#  ['refrigerators'],
#  ['hob'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['video', 'video'],
#  ['hair_cutter', 'hair_cutter', 'hair_cutter'],
#  ['smartphone'],
#  ['microwave'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['oven'],
#  ['oven'],
#  ['refrigerators'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['vacuum'],
#  ['shoes'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['tv', 'tv', 'tv', 'tv', 'tv'],
#  ['tv'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['ironing_board'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['headphone',
#   'headphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'tablet',
#   'smartphone'],
#  ['tablet'],
#  ['skates', 'skates', 'desktop'],
#  ['smartphone', 'smartphone'],
#  ['notebook', 'hdd', 'memory'],
#  ['smartphone'],
#  ['smartphone'],
#  ['washer', 'tv'],
#  ['microwave'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['clocks'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['tv'],
#  ['smartphone'],
#  ['smartphone'],
#  ['grill'],
#  ['smartphone'],
#  ['kettle'],
#  ['kettle'],
#  ['smartphone',
#   'clocks',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'headphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['mouse'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['smartphone'],
#  ['scales'],
#  ['smartphone'],
#  ['cartrige', 'cartrige'],
#  ['coffee_machine'],
#  ['shoes'],
#  ['smartphone', 'clocks', 'clocks', 'clocks'],
#  ['drill', 'memory'],
#  ['subwoofer'],
#  ['blanket',
#   'iron',
#   'scales',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'tablet'],
#  ['vacuum'],
#  ['vacuum'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['hair_cutter'],
#  ['air_heater'],
#  ['washer', 'blender'],
#  ['blender', 'vacuum', 'microphone'],
#  ['tv', 'meat_grinder', 'tv', 'cabinet', 'mixer'],
#  ['drill'],
#  ['smartphone'],
#  ['clocks'],
#  ['washer', 'tv', 'meat_grinder', 'meat_grinder', 'meat_grinder'],
#  ['piano'],
#  ['smartphone'],
#  ['clocks', 'clocks'],
#  ['smartphone', 'vacuum', 'vacuum', 'clocks'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'headphone', 'headphone'],
#  ['smartphone', 'smartphone'],
#  ['acoustic'],
#  ['smartphone'],
#  ['monitor',
#   'notebook',
#   'notebook',
#   'notebook',
#   'monitor',
#   'monitor',
#   'monitor'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['refrigerators'],
#  ['headphone', 'smartphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['belt'],
#  ['tonometer', 'clocks', 'clocks', 'clocks', 'subwoofer', 'vacuum'],
#  ['headphone'],
#  ['coffee_grinder', 'coffee_grinder', 'grill', 'grill'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['tv'],
#  ['smartphone', 'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['desktop'],
#  ['smartphone'],
#  ['smartphone'],
#  ['printer', 'printer', 'desktop'],
#  ['smartphone'],
#  ['headphone',
#   'headphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['swing'],
#  ['monitor'],
#  ['headphone', 'headphone', 'headphone'],
#  ['kettle'],
#  ['smartphone'],
#  ['smartphone', 'washer', 'smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'headphone', 'tv'],
#  ['smartphone'],
#  ['smartphone'],
#  ['vacuum', 'smartphone', 'smartphone', 'smartphone'],
#  ['notebook'],
#  ['microwave'],
#  ['notebook', 'notebook'],
#  ['clocks'],
#  ['swing'],
#  ['hair_cutter'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'clocks'],
#  ['smartphone'],
#  ['iron', 'carriage'],
#  ['notebook',
#   'notebook',
#   'notebook',
#   'tv',
#   'tv',
#   'tv',
#   'tv',
#   'tv',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'smartphone',
#   'microwave',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop',
#   'desktop'],
#  ['tablet'],
#  ['smartphone', 'smartphone'],
#  ['headphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['notebook'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['water_heater'],
#  ['refrigerators'],
#  ['toys'],
#  ['scales'],
#  ['kettle'],
#  ['clocks'],
#  ['compressor', 'tv'],
#  ['water_heater', 'water_heater', 'water_heater', 'water_heater'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['dishwasher',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'notebook',
#   'smartphone'],
#  ['telephone'],
#  ['headphone'],
#  ['vacuum'],
#  ['headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone'],
#  ['washer'],
#  ['smartphone', 'smartphone'],
#  ['vacuum'],
#  ['microwave', 'microwave'],
#  ['headphone', 'headphone', 'headphone', 'headphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone', 'headphone', 'clocks', 'clocks', 'headphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['alarm', 'player'],
#  ['vacuum'],
#  ['microwave'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'ballet_shoes', 'shoes'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['tv'],
#  ['clocks', 'tv'],
#  ['grill'],
#  ['smartphone'],
#  ['headphone'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['notebook'],
#  ['smartphone'],
#  ['washer'],
#  ['microwave', 'meat_grinder', 'piano', 'acoustic', 'meat_grinder'],
#  ['oven'],
#  ['smartphone'],
#  ['headphone', 'hob'],
#  ['smartphone'],
#  ['smartphone'],
#  ['headphone'],
#  ['smartphone'],
#  ['vacuum'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone', 'clocks', 'clocks'],
#  ['faucet', 'hood'],
#  ['meat_grinder', 'meat_grinder', 'meat_grinder'],
#  ['smartphone'],
#  ['microwave'],
#  ['washer'],
#  ['notebook', 'water_heater'],
#  ['smartphone', 'shoes', 'smartphone'],
#  ['smartphone'],
#  ['clocks', 'clocks', 'smartphone'],
#  ['notebook', 'washer'],
#  ['swing', 'swing', 'carriage', 'carriage', 'chair', 'chair'],
#  ['tv', 'smartphone'],
#  ['video', 'video'],
#  ['headphone', 'headphone'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['kettle',
#   'sewing_machine',
#   'sewing_machine',
#   'clocks',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'skates',
#   'kettle'],
#  ['smartphone', 'drill', 'smartphone'],
#  ['headphone', 'headphone', 'smartphone'],
#  ['shoes', 'kettle', 'shoes'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['videoregister',
#   'alarm',
#   'videoregister',
#   'player',
#   'alarm',
#   'videoregister',
#   'videoregister',
#   'alarm',
#   'alarm',
#   'alarm',
#   'alarm',
#   'player',
#   'player',
#   'alarm'],
#  ['smartphone'],
#  ['monitor'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['headphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['smartphone'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['grill', 'grill'],
#  ['smartphone', 'smartphone'],
#  ['clocks'],
#  ['smartphone'],
#  ['microwave'],
#  ['smartphone'],
#  ['drill'],
#  ['smartphone', 'tv', 'smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['tv'],
#  ['smartphone', 'smartphone', 'smartphone', 'clocks', 'smartphone'],
#  ['blender',
#   'tablet',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'coffee_grinder',
#   'coffee_grinder',
#   'grill',
#   'grill',
#   'refrigerators',
#   'smartphone'],
#  ['washer'],
#  ['smartphone'],
#  ['microwave'],
#  ['smartphone', 'smartphone'],
#  ['smartphone', 'clocks', 'smartphone', 'smartphone', 'smartphone'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'projector',
#   'projector',
#   'tv',
#   'tv',
#   'tv',
#   'tv',
#   'grill',
#   'smartphone',
#   'refrigerators',
#   'refrigerators'],
#  ['refrigerators'],
#  ['notebook'],
#  ['smartphone'],
#  ['smartphone'],
#  ['toys'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'diapers'],
#  ['smartphone', 'smartphone'],
#  ['tv'],
#  ['smartphone'],
#  ['smartphone'],
#  ['headphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['smartphone'],
#  ['vacuum', 'tv', 'kettle'],
#  ['clocks'],
#  ['shoes', 'drill'],
#  ['mixer', 'mixer'],
#  ['shoes', 'shoes'],
#  ['tv', 'tv', 'tv', 'tv', 'tv', 'blender'],
#  ['headphone'],
#  ['clocks', 'clocks'],
#  ['smartphone'],
#  ['smartphone'],
#  ['shoes', 'shoes', 'shoes', 'shoes', 'tablet'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['iron'],
#  ['smartphone', 'tv'],
#  ['tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'clocks',
#   'tablet'],
#  ['headphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['air_heater', 'air_heater'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['smartphone'],
#  ['headphone'],
#  ['grill'],
#  ['smartphone'],
#  ['ironing_board', 'shoes', 'shoes'],
#  ['scales', 'scales', 'scales', 'scales', 'sewing_machine'],
#  ['desktop'],
#  ['smartphone'],
#  ['monitor'],
#  ['refrigerators',
#   'refrigerators',
#   'refrigerators',
#   'refrigerators',
#   'refrigerators',
#   'refrigerators'],
#  ['desktop'],
#  ['washer', 'smartphone'],
#  ['telephone'],
#  ['light'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['chair'],
#  ['smartphone'],
#  ['smartphone'],
#  ['air_heater'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['washer',
#   'shoes',
#   'shoes',
#   'shoes',
#   'shoes',
#   'vacuum',
#   'shoes',
#   'shoes',
#   'shoes'],
#  ['refrigerators', 'washer'],
#  ['welding'],
#  ['videoregister'],
#  ['vacuum'],
#  ['smartphone'],
#  ['headphone', 'headphone'],
#  ['smartphone',
#   'vacuum',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['table'],
#  ['tv'],
#  ['toys'],
#  ['shoes'],
#  ['vacuum', 'vacuum'],
#  ['smartphone'],
#  ['smartphone'],
#  ['shoes', 'keds'],
#  ['shoes'],
#  ['smartphone', 'iron'],
#  ['tv'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['washer', 'tv', 'iron', 'vacuum', 'washer', 'dishwasher'],
#  ['subwoofer', 'subwoofer'],
#  ['alarm'],
#  ['tv'],
#  ['smartphone', 'tv'],
#  ['headphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['subwoofer'],
#  ['smartphone'],
#  ['tv'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['headphone'],
#  ['smartphone'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['smartphone'],
#  ['water_heater'],
#  ['refrigerators', 'refrigerators', 'refrigerators'],
#  ['tv'],
#  ['alarm'],
#  ['smartphone'],
#  ['smartphone'],
#  ['videocards', 'motherboard'],
#  ['smartphone', 'smartphone'],
#  ['smartphone', 'tablet', 'tablet', 'tablet'],
#  ['notebook'],
#  ['smartphone'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['smartphone'],
#  ['headphone'],
#  ['smartphone'],
#  ['headphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['washer', 'washer', 'washer'],
#  ['shoes'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['clocks'],
#  ['smartphone'],
#  ['tv', 'tv'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['clocks'],
#  ['smartphone', 'clocks'],
#  ['carriage', 'carriage'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['clocks'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'notebook', 'notebook'],
#  ['headphone'],
#  ['headphone', 'smartphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['blender'],
#  ['smartphone'],
#  ['smartphone'],
#  ['hair_cutter'],
#  ['tv'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['hair_cutter'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['oven'],
#  ['smartphone'],
#  ['drill', 'drill'],
#  ['tv'],
#  ['tv'],
#  ['headphone'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['generator'],
#  ['smartphone', 'headphone'],
#  ['printer'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'winch'],
#  ['washer'],
#  ['tablet'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['vacuum'],
#  ['vacuum'],
#  ['videoregister', 'videoregister'],
#  ['headphone'],
#  ['tv'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['smartphone', 'notebook', 'notebook', 'notebook', 'notebook', 'bed'],
#  ['headphone'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['tv'],
#  ['photo',
#   'photo',
#   'photo',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'photo',
#   'desktop',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'notebook',
#   'notebook',
#   'smartphone',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'keds',
#   'shoes',
#   'notebook',
#   'notebook',
#   'photo',
#   'notebook',
#   'photo',
#   'headphone',
#   'headphone',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'headphone',
#   'notebook',
#   'notebook',
#   'headphone',
#   'notebook',
#   'notebook'],
#  ['telephone',
#   'shoes',
#   'headphone',
#   'tablet',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'smartphone',
#   'headphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'headphone'],
#  ['headphone'],
#  ['videocards', 'videocards', 'videocards'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['smartphone'],
#  ['drill', 'drill', 'tablet'],
#  ['notebook', 'notebook', 'notebook'],
#  ['welding', 'saw'],
#  ['videoregister', 'headphone', 'headphone'],
#  ['smartphone', 'grill'],
#  ['smartphone', 'smartphone', 'hdd'],
#  ['tv'],
#  ['coffee_machine', 'coffee_machine'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['refrigerators', 'microwave', 'microwave'],
#  ['headphone'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'headphone',
#   'headphone'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'headphone',
#   'smartphone',
#   'smartphone',
#   'clocks',
#   'headphone',
#   'headphone',
#   'headphone',
#   'smartphone'],
#  ['microwave', 'microwave'],
#  ['smartphone', 'smartphone'],
#  ['dishwasher', 'tv'],
#  ['generator',
#   'smartphone',
#   'smartphone',
#   'sewing_machine',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'carriage',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'diapers',
#   'smartphone',
#   'smartphone',
#   'skates',
#   'skates',
#   'air_heater',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['kettle',
#   'blanket',
#   'blanket',
#   'blanket',
#   'ironing_board',
#   'ironing_board',
#   'headphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['tablet'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['tv'],
#  ['headphone'],
#  ['tv'],
#  ['smartphone'],
#  ['vacuum', 'headphone'],
#  ['mouse', 'desktop', 'desktop'],
#  ['washer'],
#  ['smartphone'],
#  ['oven', 'smartphone'],
#  ['smartphone', 'smartphone', 'tv'],
#  ['kettle'],
#  ['notebook'],
#  ['toster'],
#  ['washer'],
#  ['smartphone'],
#  ['tv'],
#  ['clocks', 'smartphone', 'smartphone'],
#  ['notebook'],
#  ['oven'],
#  ['refrigerators'],
#  ['smartphone', 'tv', 'smartphone'],
#  ['vacuum',
#   'vacuum',
#   'vacuum',
#   'vacuum',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'coffee_machine',
#   'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['tv'],
#  ['cabinet', 'cabinet'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['hood'],
#  ['monitor'],
#  ['clocks'],
#  ['desktop'],
#  ['coffee_machine', 'vacuum'],
#  ['smartphone'],
#  ['smartphone'],
#  ['tv'],
#  ['smartphone'],
#  ['headphone', 'headphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['smartphone'],
#  ['headphone', 'headphone', 'smartphone', 'smartphone'],
#  ['hood'],
#  ['smartphone'],
#  ['kettle'],
#  ['air_conditioner'],
#  ['ironing_board'],
#  ['washer', 'tv'],
#  ['washer',
#   'washer',
#   'smartphone',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer',
#   'washer'],
#  ['keyboard', 'keyboard'],
#  ['smartphone', 'headphone'],
#  ['clocks'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['headphone'],
#  ['smartphone', 'smartphone', 'scales'],
#  ['washer'],
#  ['notebook', 'notebook'],
#  ['refrigerators', 'washer'],
#  ['blender'],
#  ['smartphone'],
#  ['chair', 'chair', 'carriage'],
#  ['smartphone'],
#  ['headphone'],
#  ['sewing_machine'],
#  ['clocks',
#   'clocks',
#   'shoes',
#   'cabinet',
#   'shoes',
#   'moccasins',
#   'shoes',
#   'shoes',
#   'shoes',
#   'vacuum',
#   'vacuum',
#   'vacuum',
#   'tv',
#   'vacuum',
#   'vacuum',
#   'desktop',
#   'cabinet',
#   'clocks',
#   'toys',
#   'vacuum',
#   'clocks',
#   'kettle',
#   'cabinet',
#   'tv',
#   'smartphone',
#   'smartphone',
#   'toys',
#   'sofa',
#   'sofa',
#   'faucet',
#   'faucet',
#   'smartphone',
#   'faucet',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'vacuum',
#   'smartphone',
#   'smartphone'],
#  ['smartphone'],
#  ['headphone'],
#  ['keds'],
#  ['smartphone'],
#  ['juicer'],
#  ['smartphone', 'notebook'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['alarm'],
#  ['grill', 'air_heater', 'smartphone', 'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['washer'],
#  ['smartphone'],
#  ['smartphone'],
#  ['clocks', 'smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['clocks'],
#  ['smartphone'],
#  ['hdd'],
#  ['alarm', 'tv'],
#  ['player'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['headphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone', 'water_heater'],
#  ['clocks',
#   'clocks',
#   'clocks',
#   'smartphone',
#   'clocks',
#   'clocks',
#   'clocks',
#   'clocks',
#   'clocks',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'alarm'],
#  ['smartphone'],
#  ['smartphone'],
#  ['tonometer', 'water_heater'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['keyboard', 'keyboard', 'keyboard'],
#  ['saw', 'smartphone'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['headphone', 'smartphone', 'headphone', 'headphone', 'smartphone'],
#  ['smartphone'],
#  ['headphone'],
#  ['tv'],
#  ['smartphone'],
#  ['alarm', 'smartphone', 'smartphone', 'smartphone', 'alarm', 'alarm'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone'],
#  ['tablet'],
#  ['smartphone', 'smartphone'],
#  ['carriage',
#   'smartphone',
#   'carriage',
#   'smartphone',
#   'vacuum',
#   'smartphone',
#   'smartphone'],
#  ['headphone'],
#  ['refrigerators',
#   'refrigerators',
#   'smartphone',
#   'refrigerators',
#   'refrigerators',
#   'refrigerators',
#   'refrigerators',
#   'refrigerators',
#   'refrigerators',
#   'scales',
#   'meat_grinder'],
#  ['smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['smartphone', 'clocks'],
#  ['microwave'],
#  ['bag'],
#  ['vacuum'],
#  ['smartphone'],
#  ['smartphone'],
#  ['notebook'],
#  ['photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'photo',
#   'smartphone',
#   'photo',
#   'photo',
#   'smartphone',
#   'photo',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'tablet',
#   'tablet',
#   'tablet',
#   'smartphone',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'tablet',
#   'headphone',
#   'headphone',
#   'smartphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'headphone',
#   'photo',
#   'headphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['scales'],
#  ['headphone'],
#  ['tv', 'microwave'],
#  ['smartphone'],
#  ['tv'],
#  ['smartphone', 'headphone', 'headphone', 'tv'],
#  ['notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'notebook',
#   'mouse',
#   'mouse',
#   'mouse',
#   'tablet',
#   'tablet',
#   'tablet',
#   'notebook',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'headphone',
#   'smartphone'],
#  ['headphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['smartphone', 'hob', 'oven'],
#  ['smartphone', 'headphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone',
#   'tv',
#   'tv',
#   'tv',
#   'refrigerators',
#   'washer',
#   'refrigerators',
#   'refrigerators',
#   'refrigerators',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['vacuum'],
#  ['sofa', 'table'],
#  ['hood', 'washer', 'vacuum', 'smartphone'],
#  ['washer', 'washer'],
#  ['desktop'],
#  ['washer', 'smartphone'],
#  ['kettle', 'smartphone'],
#  ['smartphone', 'smartphone', 'chair', 'smartphone', 'clocks'],
#  ['smartphone'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['smartphone'],
#  ['clocks'],
#  ['headphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone',
#   'smartphone',
#   'washer',
#   'smartphone',
#   'washer',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'washer',
#   'washer'],
#  ['headphone'],
#  ['tv', 'tv'],
#  ['notebook'],
#  ['smartphone'],
#  ['smartphone', 'memory'],
#  ['smartphone'],
#  ['smartphone', 'smartphone'],
#  ['notebook', 'fan', 'coffee_machine', 'coffee_machine', 'coffee_machine'],
#  ['clocks'],
#  ['carriage'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'subwoofer'],
#  ['smartphone', 'smartphone'],
#  ['drill', 'smartphone'],
#  ['smartphone', 'smartphone', 'smartphone'],
#  ['smartphone'],
#  ['scales', 'notebook'],
#  ['refrigerators', 'oven', 'hob', 'hood', 'washer'],
#  ['smartphone'],
#  ['smartphone'],
#  ['tv', 'vacuum', 'oven', 'oven', 'oven', 'oven'],
#  ['smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone',
#   'smartphone'],
#  ['clocks', 'smartphone'],
#  ['headphone', 'smartphone'],
#  ['notebook'],
#  ['table'],
#  ['smartphone'],
#  ['washer'],
#  ['vacuum'],
#  ['notebook', 'tv', 'tv'],
#  ['washer'],
#  ['smartphone', 'smartphone', 'smartphone', 'smartphone'],
#  ['headphone',
#   'headphone',
#   'headphone',
#   'toys',
#   'headphone',
#   'headphone',
#   'headphone',
#   'scales',
#   'scales'],
#  ['vacuum', 'smartphone'],
#  ['blanket'],
#  ['smartphone'],
#  ['smartphone'],
#  ['kettle', 'kettle'],
#  ['vacuum', 'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['smartphone', 'smartphone'],
#  ['cooler'],
#  ['smartphone'],
#  ...]

# %%
rules = apriori(transactions, min_support=0.005, min_confidence=0.25, min_length=2)

# %%
# step 5
res = list(rules)
res
# Out:
# [RelationRecord(items=frozenset({'smartphone'}), support=0.6033093940461643, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'smartphone'}), confidence=0.6033093940461643, lift=1.0)]),
#  RelationRecord(items=frozenset({'clocks', 'smartphone'}), support=0.013677629260905745, ordered_statistics=[OrderedStatistic(items_base=frozenset({'clocks'}), items_add=frozenset({'smartphone'}), confidence=0.32125720825813264, lift=0.5324916393288425)]),
#  RelationRecord(items=frozenset({'headphone', 'smartphone'}), support=0.023361420764208017, ordered_statistics=[OrderedStatistic(items_base=frozenset({'headphone'}), items_add=frozenset({'smartphone'}), confidence=0.29669388046557016, lift=0.4917773258522601)]),
#  RelationRecord(items=frozenset({'notebook', 'smartphone'}), support=0.011331179297264474, ordered_statistics=[OrderedStatistic(items_base=frozenset({'notebook'}), items_add=frozenset({'smartphone'}), confidence=0.2979646148538761, lift=0.49388359901963713)]),
#  RelationRecord(items=frozenset({'tv', 'smartphone'}), support=0.015407480152631697, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tv'}), items_add=frozenset({'smartphone'}), confidence=0.25285270507181745, lift=0.4191095109194828)])]
